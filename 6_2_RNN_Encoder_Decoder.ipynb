# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
def n(digits=3):
    number = ''
    for i in range(np.random.randint(1, digits + 1)):
        number += np.random.choice(list('0123456789'))
    return int(number)

# %%
def padding(chars, maxlen):
    return chars + ' ' * (maxlen - len(chars))

# %%
N = 20000
N_train = int(N * 0.9)
N_validation = N - N_train

digits = 3
input_digits = digits * 2 + 1
output_digits = digits + 1

added = set()
questions = []
answers = []

while len(questions) < N:
    a, b = n(), n()
    
    pair = tuple(sorted((a, b)))
    if pair in added:
        continue
        
    question = '{}+{}'.format(a, b)
    question = padding(question, input_digits)
    answer = str(a + b)
    answer = padding(answer, output_digits)
    
    added.add(pair)
    questions.append(question)
    answers.append(answer)

# %%
chars = '0123456789+ '
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
X = np.zeros((len(questions), input_digits, len(chars)), dtype=np.integer)
Y = np.zeros((len(questions), digits + 1, len(chars)), dtype=np.integer)

for i in range(N):
    for t, char in enumerate(questions[i]):
        X[i, t, char_indices[char]] = 1
    for t, char in enumerate(answers[i]):
        Y[i, t, char_indices[char]] = 1

X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, train_size=N_train)

# %%
def inference(x, y, n_batch, is_training,
              input_digits=None, output_digits=None,
              n_hidden=None, n_out=None):
    def weight_variable(shape):
        initial = tf.truncated_normal(shape, stddev=0.01)
        return tf.Variable(initial)

    def bias_variable(shape):
        initial = tf.zeros(shape, dtype=tf.float32)
        return tf.Variable(initial)

    # Encoder
    encoder = tf.contrib.rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)
    state = encoder.zero_state(n_batch, tf.float32)
    encoder_outputs = []
    encoder_states = []

    with tf.variable_scope('Encoder'):
        for t in range(input_digits):
            if t > 0:
                tf.get_variable_scope().reuse_variables()
            (output, state) = encoder(x[:, t, :], state)
            encoder_outputs.append(output)
            encoder_states.append(state)

    # Decoder
    decoder = tf.contrib.rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)
    state = encoder_states[-1]
    decoder_outputs = [encoder_outputs[-1]]

    # 出力層の重みとバイアスを事前に定義
    V = weight_variable([n_hidden, n_out])
    c = bias_variable([n_out])
    outputs = []

    with tf.variable_scope('Decoder'):
        for t in range(1, output_digits):
            if t > 1:
                tf.get_variable_scope().reuse_variables()

            if is_training is True:
                (output, state) = decoder(y[:, t-1, :], state)
            else:
                # 直前の出力を入力に用いる
                linear = tf.matmul(decoder_outputs[-1], V) + c
                out = tf.nn.softmax(linear)
                outputs.append(out)
                out = tf.one_hot(tf.argmax(out, -1), depth=output_digits)
                (output, state) = decoder(out, state)

            decoder_outputs.append(output)

    if is_training is True:
        output = tf.reshape(tf.concat(decoder_outputs, axis=1),
                            [-1, output_digits, n_hidden])

        linear = tf.einsum('ijk,kl->ijl', output, V) + c
        # linear = tf.matmul(output, V) + c
        return tf.nn.softmax(linear)
    else:
        # 最後の出力を求める
        linear = tf.matmul(decoder_outputs[-1], V) + c
        out = tf.nn.softmax(linear)
        outputs.append(out)

        output = tf.reshape(tf.concat(outputs, axis=1),
                            [-1, output_digits, n_out])
        return output

# %%
def loss(y, t):
    return tf.reduce_mean(tf.square(y-t))

def training(loss):
    optimizer = tf.train.AdamOptimizer(learning_rate=0.001, beta1=0.9, beta2=0.999)
    
    train_step = optimizer.minimize(loss)
    return train_step

# %%
def accuracy(y, t):
    correct_prediction = tf.equal(tf.argmax(y, -1), tf.argmax(t, -1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    return accuracy

# %%
n_in = len(chars)
n_hidden = 128
n_out = len(chars)

x = tf.placeholder(tf.float32, shape=[None, input_digits, n_in])
t = tf.placeholder(tf.float32, shape=[None, output_digits, n_out])
n_batch = tf.placeholder(tf.int32, shape=[])
is_training = tf.placeholder(tf.bool)

y = inference(x, t, n_batch, is_training,
                  input_digits=input_digits,
                  output_digits=output_digits,
                  n_hidden=n_hidden, n_out=n_out)
loss = loss(y, t)
train_step = training(loss)

acc = accuracy(y, t)
history = {
        'val_loss': [],
        'val_acc': []
    }

# %%
epochs = 200
batch_size = 200

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

n_batches = N_train // batch_size

# %%
for epoch in range(epochs):
    print('=' * 10)
    print('Epoch:', epoch)
    print('=' * 10)

    X_, Y_ = shuffle(X_train, Y_train)

    for i in range(n_batches):
        start = i * batch_size
        end = start + batch_size

        sess.run(train_step, feed_dict={
            x: X_[start:end],
            t: Y_[start:end],
            n_batch: batch_size,
            is_training: True
        })

    # 検証データを用いた評価
    val_loss = loss.eval(session=sess, feed_dict={
        x: X_validation,
        t: Y_validation,
        n_batch: N_validation,
        is_training: False
    })
    val_acc = acc.eval(session=sess, feed_dict={
        x: X_validation,
        t: Y_validation,
        n_batch: N_validation,
        is_training: False
    })

    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)
    print('validation loss:', val_loss)
    print('validation acc: ', val_acc)
    
    if epoch % 50 == 0:
        # 検証データからランダムに問題を選んで答え合わせ
        for i in range(10):
            index = np.random.randint(0, N_validation)
            question = X_validation[np.array([index])]
            answer = Y_validation[np.array([index])]
            prediction = y.eval(session=sess, feed_dict={
                x: question,
                # t: answer,
                n_batch: 1,
                is_training: False
            })
            question = question.argmax(axis=-1)
            answer = answer.argmax(axis=-1)
            prediction = np.argmax(prediction, -1)

            q = ''.join(indices_char[i] for i in question[0])
            a = ''.join(indices_char[i] for i in answer[0])
            p = ''.join(indices_char[i] for i in prediction[0])

            print('-' * 10)
            print('Q:  ', q)
            print('A:  ', p)
            print('T/F:', end=' ')
            if a == p:
                print('T')
            else:
                print('F')
        print('-' * 10)
# Out:
# ==========
# Epoch: 0
# ==========
# validation loss: 0.058947
# validation acc:  0.34775
# ----------
# Q:   31+55
# A:   11
# T/F: F
# ----------
# Q:   45+21
# A:   11
# T/F: F
# ----------
# Q:   17+351
# A:   11
# T/F: F
# ----------
# Q:   319+237
# A:   111
# T/F: F
# ----------
# Q:   984+2
# A:   11
# T/F: F
# ----------
# Q:   23+46
# A:   11
# T/F: F
# ----------
# Q:   0+522
# A:   11
# T/F: F
# ----------
# Q:   58+15
# A:   11
# T/F: F
# ----------
# Q:   609+61
# A:   111
# T/F: F
# ----------
# Q:   155+560
# A:   111
# T/F: F
# ----------
# ==========
# Epoch: 1
# ==========
# validation loss: 0.0583942
# validation acc:  0.348
# ==========
# Epoch: 2
# ==========
# validation loss: 0.0580695
# validation acc:  0.3515
# ==========
# Epoch: 3
# ==========
# validation loss: 0.057775
# validation acc:  0.352875
# ==========
# Epoch: 4
# ==========
# validation loss: 0.0575561
# validation acc:  0.355625
# ==========
# Epoch: 5
# ==========
# validation loss: 0.0574111
# validation acc:  0.358125
# ==========
# Epoch: 6
# ==========
# validation loss: 0.0563534
# validation acc:  0.362625
# ==========
# Epoch: 7
# ==========
# validation loss: 0.0553686
# validation acc:  0.374
# ==========
# Epoch: 8
# ==========
# validation loss: 0.0541713
# validation acc:  0.394625
# ==========
# Epoch: 9
# ==========
# validation loss: 0.0528015
# validation acc:  0.41775
# ==========
# Epoch: 10
# ==========
# validation loss: 0.0514004
# validation acc:  0.441375
# ==========
# Epoch: 11
# ==========
# validation loss: 0.0499028
# validation acc:  0.453125
# ==========
# Epoch: 12
# ==========
# validation loss: 0.0490961
# validation acc:  0.463375
# ==========
# Epoch: 13
# ==========
# validation loss: 0.0473599
# validation acc:  0.478125
# ==========
# Epoch: 14
# ==========
# validation loss: 0.0461217
# validation acc:  0.495375
# ==========
# Epoch: 15
# ==========
# validation loss: 0.0451856
# validation acc:  0.507625
# ==========
# Epoch: 16
# ==========
# validation loss: 0.0445453
# validation acc:  0.516625
# ==========
# Epoch: 17
# ==========
# validation loss: 0.0438048
# validation acc:  0.527625
# ==========
# Epoch: 18
# ==========
# validation loss: 0.0432901
# validation acc:  0.53325
# ==========
# Epoch: 19
# ==========
# validation loss: 0.0424279
# validation acc:  0.541125
# ==========
# Epoch: 20
# ==========
# validation loss: 0.0417584
# validation acc:  0.546125
# ==========
# Epoch: 21
# ==========
# validation loss: 0.0412644
# validation acc:  0.557875
# ==========
# Epoch: 22
# ==========
# validation loss: 0.0406951
# validation acc:  0.55775
# ==========
# Epoch: 23
# ==========
# validation loss: 0.0401461
# validation acc:  0.565
# ==========
# Epoch: 24
# ==========
# validation loss: 0.0398274
# validation acc:  0.566375
# ==========
# Epoch: 25
# ==========
# validation loss: 0.0394145
# validation acc:  0.5745
# ==========
# Epoch: 26
# ==========
# validation loss: 0.0385609
# validation acc:  0.581375
# ==========
# Epoch: 27
# ==========
# validation loss: 0.0383894
# validation acc:  0.580875
# ==========
# Epoch: 28
# ==========
# validation loss: 0.0388165
# validation acc:  0.580375
# ==========
# Epoch: 29
# ==========
# validation loss: 0.0375676
# validation acc:  0.595
# ==========
# Epoch: 30
# ==========
# validation loss: 0.0371362
# validation acc:  0.600125
# ==========
# Epoch: 31
# ==========
# validation loss: 0.0368828
# validation acc:  0.603125
# ==========
# Epoch: 32
# ==========
# validation loss: 0.0363214
# validation acc:  0.608375
# ==========
# Epoch: 33
# ==========
# validation loss: 0.0361996
# validation acc:  0.6115
# ==========
# Epoch: 34
# ==========
# validation loss: 0.0357994
# validation acc:  0.619
# ==========
# Epoch: 35
# ==========
# validation loss: 0.0354875
# validation acc:  0.615625
# ==========
# Epoch: 36
# ==========
# validation loss: 0.0352368
# validation acc:  0.61925
# ==========
# Epoch: 37
# ==========
# validation loss: 0.0348169
# validation acc:  0.62675
# ==========
# Epoch: 38
# ==========
# validation loss: 0.034954
# validation acc:  0.62725
# ==========
# Epoch: 39
# ==========
# validation loss: 0.0352421
# validation acc:  0.62325
# ==========
# Epoch: 40
# ==========
# validation loss: 0.0343047
# validation acc:  0.63575
# ==========
# Epoch: 41
# ==========
# validation loss: 0.0340595
# validation acc:  0.636375
# ==========
# Epoch: 42
# ==========
# validation loss: 0.0338429
# validation acc:  0.63975
# ==========
# Epoch: 43
# ==========
# validation loss: 0.0335078
# validation acc:  0.641625
# ==========
# Epoch: 44
# ==========
# validation loss: 0.033461
# validation acc:  0.64375
# ==========
# Epoch: 45
# ==========
# validation loss: 0.0332802
# validation acc:  0.645375
# ==========
# Epoch: 46
# ==========
# validation loss: 0.0335982
# validation acc:  0.644375
# ==========
# Epoch: 47
# ==========
# validation loss: 0.0329602
# validation acc:  0.646
# ==========
# Epoch: 48
# ==========
# validation loss: 0.0325533
# validation acc:  0.65475
# ==========
# Epoch: 49
# ==========
# validation loss: 0.032642
# validation acc:  0.652625
# ==========
# Epoch: 50
# ==========
# validation loss: 0.032402
# validation acc:  0.65425
# ----------
# Q:   5+580
# A:   585
# T/F: T
# ----------
# Q:   81+843
# A:   927
# T/F: F
# ----------
# Q:   193+13
# A:   213
# T/F: F
# ----------
# Q:   353+147
# A:   551
# T/F: F
# ----------
# Q:   9+380
# A:   386
# T/F: F
# ----------
# Q:   57+40
# A:   10
# T/F: F
# ----------
# Q:   93+5
# A:   96
# T/F: F
# ----------
# Q:   808+13
# A:   820
# T/F: F
# ----------
# Q:   9+634
# A:   641
# T/F: F
# ----------
# Q:   771+47
# A:   817
# T/F: F
# ----------
# ==========
# Epoch: 51
# ==========
# validation loss: 0.0324455
# validation acc:  0.65625
# ==========
# Epoch: 52
# ==========
# validation loss: 0.0320768
# validation acc:  0.66225
# ==========
# Epoch: 53
# ==========
# validation loss: 0.0321583
# validation acc:  0.660875
# ==========
# Epoch: 54
# ==========
# validation loss: 0.0317706
# validation acc:  0.664875
# ==========
# Epoch: 55
# ==========
# validation loss: 0.0316942
# validation acc:  0.66725
# ==========
# Epoch: 56
# ==========
# validation loss: 0.0313772
# validation acc:  0.670625
# ==========
# Epoch: 57
# ==========
# validation loss: 0.031291
# validation acc:  0.671125
# ==========
# Epoch: 58
# ==========
# validation loss: 0.0312366
# validation acc:  0.672375
# ==========
# Epoch: 59
# ==========
# validation loss: 0.0311991
# validation acc:  0.67225
# ==========
# Epoch: 60
# ==========
# validation loss: 0.0310499
# validation acc:  0.675375
# ==========
# Epoch: 61
# ==========
# validation loss: 0.0307444
# validation acc:  0.677375
# ==========
# Epoch: 62
# ==========
# validation loss: 0.0307707
# validation acc:  0.67725
# ==========
# Epoch: 63
# ==========
# validation loss: 0.0306254
# validation acc:  0.683
# ==========
# Epoch: 64
# ==========
# validation loss: 0.0306907
# validation acc:  0.684875
# ==========
# Epoch: 65
# ==========
# validation loss: 0.0303123
# validation acc:  0.687625
# ==========
# Epoch: 66
# ==========
# validation loss: 0.0302564
# validation acc:  0.689625
# ==========
# Epoch: 67
# ==========
# validation loss: 0.0303266
# validation acc:  0.691
# ==========
# Epoch: 68
# ==========
# validation loss: 0.0300821
# validation acc:  0.693375
# ==========
# Epoch: 69
# ==========
# validation loss: 0.0296536
# validation acc:  0.69975
# ==========
# Epoch: 70
# ==========
# validation loss: 0.0299164
# validation acc:  0.69525
# ==========
# Epoch: 71
# ==========
# validation loss: 0.0294741
# validation acc:  0.702
# ==========
# Epoch: 72
# ==========
# validation loss: 0.0295659
# validation acc:  0.702625
# ==========
# Epoch: 73
# ==========
# validation loss: 0.0291753
# validation acc:  0.705625
# ==========
# Epoch: 74
# ==========
# validation loss: 0.0290175
# validation acc:  0.712
# ==========
# Epoch: 75
# ==========
# validation loss: 0.0288173
# validation acc:  0.711625
# ==========
# Epoch: 76
# ==========
# validation loss: 0.0289444
# validation acc:  0.713625
# ==========
# Epoch: 77
# ==========
# validation loss: 0.0286503
# validation acc:  0.714125
# ==========
# Epoch: 78
# ==========
# validation loss: 0.0285886
# validation acc:  0.7185
# ==========
# Epoch: 79
# ==========
# validation loss: 0.0284076
# validation acc:  0.718375
# ==========
# Epoch: 80
# ==========
# validation loss: 0.0284006
# validation acc:  0.721
# ==========
# Epoch: 81
# ==========
# validation loss: 0.0280918
# validation acc:  0.7225
# ==========
# Epoch: 82
# ==========
# validation loss: 0.0280213
# validation acc:  0.726125
# ==========
# Epoch: 83
# ==========
# validation loss: 0.02809
# validation acc:  0.723625
# ==========
# Epoch: 84
# ==========
# validation loss: 0.0277758
# validation acc:  0.73025
# ==========
# Epoch: 85
# ==========
# validation loss: 0.0278616
# validation acc:  0.733125
# ==========
# Epoch: 86
# ==========
# validation loss: 0.0278751
# validation acc:  0.729
# ==========
# Epoch: 87
# ==========
# validation loss: 0.0275019
# validation acc:  0.737375
# ==========
# Epoch: 88
# ==========
# validation loss: 0.0277842
# validation acc:  0.7295
# ==========
# Epoch: 89
# ==========
# validation loss: 0.0274734
# validation acc:  0.736625
# ==========
# Epoch: 90
# ==========
# validation loss: 0.0272004
# validation acc:  0.739375
# ==========
# Epoch: 91
# ==========
# validation loss: 0.0271017
# validation acc:  0.740625
# ==========
# Epoch: 92
# ==========
# validation loss: 0.0268187
# validation acc:  0.744125
# ==========
# Epoch: 93
# ==========
# validation loss: 0.0268385
# validation acc:  0.745125
# ==========
# Epoch: 94
# ==========
# validation loss: 0.0266483
# validation acc:  0.746875
# ==========
# Epoch: 95
# ==========
# validation loss: 0.0267023
# validation acc:  0.748375
# ==========
# Epoch: 96
# ==========
# validation loss: 0.0263825
# validation acc:  0.751625
# ==========
# Epoch: 97
# ==========
# validation loss: 0.0265069
# validation acc:  0.75175
# ==========
# Epoch: 98
# ==========
# validation loss: 0.0263362
# validation acc:  0.74975
# ==========
# Epoch: 99
# ==========
# validation loss: 0.0265431
# validation acc:  0.752
# ==========
# Epoch: 100
# ==========
# validation loss: 0.0259503
# validation acc:  0.754375
# ----------
# Q:   5+607
# A:   612
# T/F: T
# ----------
# Q:   543+5
# A:   548
# T/F: T
# ----------
# Q:   59+748
# A:   707
# T/F: F
# ----------
# Q:   97+92
# A:   180
# T/F: F
# ----------
# Q:   334+5
# A:   339
# T/F: T
# ----------
# Q:   393+8
# A:   402
# T/F: F
# ----------
# Q:   76+605
# A:   684
# T/F: F
# ----------
# Q:   3+283
# A:   285
# T/F: F
# ----------
# Q:   718+105
# A:   788
# T/F: F
# ----------
# Q:   282+93
# A:   375
# T/F: T
# ----------
# ==========
# Epoch: 101
# ==========
# validation loss: 0.0261444
# validation acc:  0.756625
# ==========
# Epoch: 102
# ==========
# validation loss: 0.0258409
# validation acc:  0.759625
# ==========
# Epoch: 103
# ==========
# validation loss: 0.0256941
# validation acc:  0.761625
# ==========
# Epoch: 104
# ==========
# validation loss: 0.0254083
# validation acc:  0.764875
# ==========
# Epoch: 105
# ==========
# validation loss: 0.0254321
# validation acc:  0.7655
# ==========
# Epoch: 106
# ==========
# validation loss: 0.0255982
# validation acc:  0.76225
# ==========
# Epoch: 107
# ==========
# validation loss: 0.0254744
# validation acc:  0.767
# ==========
# Epoch: 108
# ==========
# validation loss: 0.0254558
# validation acc:  0.770125
# ==========
# Epoch: 109
# ==========
# validation loss: 0.0251718
# validation acc:  0.771625
# ==========
# Epoch: 110
# ==========
# validation loss: 0.0252033
# validation acc:  0.7695
# ==========
# Epoch: 111
# ==========
# validation loss: 0.0247419
# validation acc:  0.778375
# ==========
# Epoch: 112
# ==========
# validation loss: 0.0248265
# validation acc:  0.776125
# ==========
# Epoch: 113
# ==========
# validation loss: 0.024587
# validation acc:  0.779125
# ==========
# Epoch: 114
# ==========
# validation loss: 0.024609
# validation acc:  0.779375
# ==========
# Epoch: 115
# ==========
# validation loss: 0.0245504
# validation acc:  0.780125
# ==========
# Epoch: 116
# ==========
# validation loss: 0.0246225
# validation acc:  0.778625
# ==========
# Epoch: 117
# ==========
# validation loss: 0.0243081
# validation acc:  0.78475
# ==========
# Epoch: 118
# ==========
# validation loss: 0.0242515
# validation acc:  0.78625
# ==========
# Epoch: 119
# ==========
# validation loss: 0.0245567
# validation acc:  0.78375
# ==========
# Epoch: 120
# ==========
# validation loss: 0.0241458
# validation acc:  0.786875
# ==========
# Epoch: 121
# ==========
# validation loss: 0.0241263
# validation acc:  0.785
# ==========
# Epoch: 122
# ==========
# validation loss: 0.0240219
# validation acc:  0.788875
# ==========
# Epoch: 123
# ==========
# validation loss: 0.0240813
# validation acc:  0.788875
# ==========
# Epoch: 124
# ==========
# validation loss: 0.0239047
# validation acc:  0.791375
# ==========
# Epoch: 125
# ==========
# validation loss: 0.0235523
# validation acc:  0.7935
# ==========
# Epoch: 126
# ==========
# validation loss: 0.0236958
# validation acc:  0.794875
# ==========
# Epoch: 127
# ==========
# validation loss: 0.0235118
# validation acc:  0.79675
# ==========
# Epoch: 128
# ==========
# validation loss: 0.0238363
# validation acc:  0.7925
# ==========
# Epoch: 129
# ==========
# validation loss: 0.0236657
# validation acc:  0.79375
# ==========
# Epoch: 130
# ==========
# validation loss: 0.0237449
# validation acc:  0.7965
# ==========
# Epoch: 131
# ==========
# validation loss: 0.0234211
# validation acc:  0.79775
# ==========
# Epoch: 132
# ==========
# validation loss: 0.0238353
# validation acc:  0.797125
# ==========
# Epoch: 133
# ==========
# validation loss: 0.0234385
# validation acc:  0.799
# ==========
# Epoch: 134
# ==========
# validation loss: 0.0233844
# validation acc:  0.79875
# ==========
# Epoch: 135
# ==========
# validation loss: 0.0234237
# validation acc:  0.79925
# ==========
# Epoch: 136
# ==========
# validation loss: 0.0232653
# validation acc:  0.800875
# ==========
# Epoch: 137
# ==========
# validation loss: 0.0236814
# validation acc:  0.796875
# ==========
# Epoch: 138
# ==========
# validation loss: 0.023097
# validation acc:  0.80225
# ==========
# Epoch: 139
# ==========
# validation loss: 0.0230414
# validation acc:  0.80125
# ==========
# Epoch: 140
# ==========
# validation loss: 0.0236576
# validation acc:  0.799625
# ==========
# Epoch: 141
# ==========
# validation loss: 0.0235049
# validation acc:  0.7995
# ==========
# Epoch: 142
# ==========
# validation loss: 0.0231055
# validation acc:  0.8055
# ==========
# Epoch: 143
# ==========
# validation loss: 0.023448
# validation acc:  0.79975
# ==========
# Epoch: 144
# ==========
# validation loss: 0.023063
# validation acc:  0.805625
# ==========
# Epoch: 145
# ==========
# validation loss: 0.0235052
# validation acc:  0.79925
# ==========
# Epoch: 146
# ==========
# validation loss: 0.0228535
# validation acc:  0.807
# ==========
# Epoch: 147
# ==========
# validation loss: 0.0233042
# validation acc:  0.804375
# ==========
# Epoch: 148
# ==========
# validation loss: 0.0230394
# validation acc:  0.80525
# ==========
# Epoch: 149
# ==========
# validation loss: 0.0233914
# validation acc:  0.80325
# ==========
# Epoch: 150
# ==========
# validation loss: 0.0230309
# validation acc:  0.807625
# ----------
# Q:   653+71
# A:   714
# T/F: F
# ----------
# Q:   836+5
# A:   841
# T/F: T
# ----------
# Q:   205+45
# A:   259
# T/F: F
# ----------
# Q:   272+5
# A:   278
# T/F: F
# ----------
# Q:   94+56
# A:   150
# T/F: T
# ----------
# Q:   71+148
# A:   219
# T/F: T
# ----------
# Q:   964+262
# A:   1245
# T/F: F
# ----------
# Q:   47+219
# A:   266
# T/F: T
# ----------
# Q:   539+100
# A:   669
# T/F: F
# ----------
# Q:   2+820
# A:   822
# T/F: T
# ----------
# ==========
# Epoch: 151
# ==========
# validation loss: 0.0231611
# validation acc:  0.808
# ==========
# Epoch: 152
# ==========
# validation loss: 0.0235577
# validation acc:  0.802375
# ==========
# Epoch: 153
# ==========
# validation loss: 0.0231594
# validation acc:  0.808375
# ==========
# Epoch: 154
# ==========
# validation loss: 0.0232227
# validation acc:  0.8085
# ==========
# Epoch: 155
# ==========
# validation loss: 0.0229891
# validation acc:  0.80875
# ==========
# Epoch: 156
# ==========
# validation loss: 0.0233513
# validation acc:  0.8075
# ==========
# Epoch: 157
# ==========
# validation loss: 0.0229917
# validation acc:  0.808125
# ==========
# Epoch: 158
# ==========
# validation loss: 0.0233257
# validation acc:  0.805875
# ==========
# Epoch: 159
# ==========
# validation loss: 0.0228226
# validation acc:  0.809375
# ==========
# Epoch: 160
# ==========
# validation loss: 0.0233657
# validation acc:  0.808875
# ==========
# Epoch: 161
# ==========
# validation loss: 0.0234501
# validation acc:  0.805625
# ==========
# Epoch: 162
# ==========
# validation loss: 0.023054
# validation acc:  0.811375
# ==========
# Epoch: 163
# ==========
# validation loss: 0.0225939
# validation acc:  0.812875
# ==========
# Epoch: 164
# ==========
# validation loss: 0.0228087
# validation acc:  0.812625
# ==========
# Epoch: 165
# ==========
# validation loss: 0.0231049
# validation acc:  0.8105
# ==========
# Epoch: 166
# ==========
# validation loss: 0.0230674
# validation acc:  0.809375
# ==========
# Epoch: 167
# ==========
# validation loss: 0.0229292
# validation acc:  0.813625
# ==========
# Epoch: 168
# ==========
# validation loss: 0.0228509
# validation acc:  0.813
# ==========
# Epoch: 169
# ==========
# validation loss: 0.0230753
# validation acc:  0.81325
# ==========
# Epoch: 170
# ==========
# validation loss: 0.0230629
# validation acc:  0.8135
# ==========
# Epoch: 171
# ==========
# validation loss: 0.0231413
# validation acc:  0.812625
# ==========
# Epoch: 172
# ==========
# validation loss: 0.0240035
# validation acc:  0.8065
# ==========
# Epoch: 173
# ==========
# validation loss: 0.0234804
# validation acc:  0.80925
# ==========
# Epoch: 174
# ==========
# validation loss: 0.0232807
# validation acc:  0.811625
# ==========
# Epoch: 175
# ==========
# validation loss: 0.0236581
# validation acc:  0.80675
# ==========
# Epoch: 176
# ==========
# validation loss: 0.024161
# validation acc:  0.804
# ==========
# Epoch: 177
# ==========
# validation loss: 0.0229335
# validation acc:  0.81375
# ==========
# Epoch: 178
# ==========
# validation loss: 0.0227543
# validation acc:  0.816
# ==========
# Epoch: 179
# ==========
# validation loss: 0.0224704
# validation acc:  0.81825
# ==========
# Epoch: 180
# ==========
# validation loss: 0.0230252
# validation acc:  0.814375
# ==========
# Epoch: 181
# ==========
# validation loss: 0.0226571
# validation acc:  0.81875
# ==========
# Epoch: 182
# ==========
# validation loss: 0.0225291
# validation acc:  0.81925
# ==========
# Epoch: 183
# ==========
# validation loss: 0.0226058
# validation acc:  0.81475
# ==========
# Epoch: 184
# ==========
# validation loss: 0.022736
# validation acc:  0.817
# ==========
# Epoch: 185
# ==========
# validation loss: 0.0225877
# validation acc:  0.818125
# ==========
# Epoch: 186
# ==========
# validation loss: 0.0225642
# validation acc:  0.818875
# ==========
# Epoch: 187
# ==========
# validation loss: 0.0228212
# validation acc:  0.816125
# ==========
# Epoch: 188
# ==========
# validation loss: 0.0235713
# validation acc:  0.812
# ==========
# Epoch: 189
# ==========
# validation loss: 0.0250364
# validation acc:  0.7975
# ==========
# Epoch: 190
# ==========
# validation loss: 0.0231821
# validation acc:  0.815625
# ==========
# Epoch: 191
# ==========
# validation loss: 0.0235502
# validation acc:  0.8115
# ==========
# Epoch: 192
# ==========
# validation loss: 0.022499
# validation acc:  0.819875
# ==========
# Epoch: 193
# ==========
# validation loss: 0.0226254
# validation acc:  0.8185
# ==========
# Epoch: 194
# ==========
# validation loss: 0.022406
# validation acc:  0.821125
# ==========
# Epoch: 195
# ==========
# validation loss: 0.022482
# validation acc:  0.820875
# ==========
# Epoch: 196
# ==========
# validation loss: 0.0225122
# validation acc:  0.821125
# ==========
# Epoch: 197
# ==========
# validation loss: 0.022578
# validation acc:  0.81825
# ==========
# Epoch: 198
# ==========
# validation loss: 0.0225661
# validation acc:  0.82175
# ==========
# Epoch: 199
# ==========
# validation loss: 0.0226493
# validation acc:  0.820625

# %%
# 検証データからランダムに問題を選んで答え合わせ
for i in range(10):
    index = np.random.randint(0, N_validation)
    question = X_validation[np.array([index])]
    answer = Y_validation[np.array([index])]
    prediction = y.eval(session=sess, feed_dict={
        x: question,
        # t: answer,
        n_batch: 1,
        is_training: False
    })
    question = question.argmax(axis=-1)
    answer = answer.argmax(axis=-1)
    prediction = np.argmax(prediction, -1)

    q = ''.join(indices_char[i] for i in question[0])
    a = ''.join(indices_char[i] for i in answer[0])
    p = ''.join(indices_char[i] for i in prediction[0])

    print('-' * 10)
    print('Q:  ', q)
    print('A:  ', p)
    print('T/F:', end=' ')
    if a == p:
        print('T')
    else:
        print('F')
print('-' * 10)
# Out:
# ----------
# Q:   8+141
# A:   149
# T/F: T
# ----------
# Q:   3+273
# A:   276
# T/F: T
# ----------
# Q:   216+920
# A:   1187
# T/F: F
# ----------
# Q:   61+857
# A:   919
# T/F: F
# ----------
# Q:   2+918
# A:   920
# T/F: T
# ----------
# Q:   2+376
# A:   378
# T/F: T
# ----------
# Q:   794+683
# A:   1590
# T/F: F
# ----------
# Q:   969+38
# A:   1005
# T/F: F
# ----------
# Q:   758+614
# A:   1366
# T/F: F
# ----------
# Q:   837+60
# A:   816
# T/F: F
# ----------

# %% [markdown]
# # Kerasによる実装

# %%
from keras.optimizers import Adam
from keras.layers import Activation, Dense
from keras.layers.core import RepeatVector
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import TimeDistributed
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

# Encoder
model.add(LSTM(n_hidden, input_shape=(input_digits, n_in)))

# Decoder
model.add(RepeatVector(output_digits))
model.add(LSTM(n_hidden, return_sequences=True))
model.add(TimeDistributed(Dense(n_out)))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy',
             optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
             metrics=['accuracy'])

# %%
epochs = 200
batch_size = 200

for epoch in range(epochs):
    model.fit(X_train, Y_train, batch_size=batch_size, epochs=1,
              validation_data=(X_validation, Y_validation))

    if epoch % 50 == 0:
    # 検証データからランダムに問題を選んで答え合わせ
        for i in range(10):
            index = np.random.randint(0, N_validation)
            question = X_validation[np.array([index])]
            answer = Y_validation[np.array([index])]
            prediction = model.predict_classes(question, verbose=0)

            question = question.argmax(axis=-1)
            answer = answer.argmax(axis=-1)

            q = ''.join(indices_char[i] for i in question[0])
            a = ''.join(indices_char[i] for i in answer[0])
            p = ''.join(indices_char[i] for i in prediction[0])

            print('-' * 10)
            print('Q:  ', q)
            print('A:  ', p)
            print('T/F:', end=' ')
            if a == p:
                print('T')
            else:
                print('F')
        print('-' * 10)
# Out:
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 5s