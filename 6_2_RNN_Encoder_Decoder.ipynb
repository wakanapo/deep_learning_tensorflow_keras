# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
# Out:
# /home/shimazu/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def n(digits=3):
    number = ''
    for i in range(np.random.randint(1, digits + 1)):
        number += np.random.choice(list('0123456789'))
    return int(number)

# %%
def padding(chars, maxlen):
    return chars + ' ' * (maxlen - len(chars))

# %%
N = 20000
N_train = int(N * 0.9)
N_validation = N - N_train

digits = 3
input_digits = digits * 2 + 1
output_digits = digits + 1

added = set()
questions = []
answers = []

while len(questions) < N:
    a, b = n(), n()
    
    pair = tuple(sorted((a, b)))
    if pair in added:
        continue
        
    question = '{}+{}'.format(a, b)
    question = padding(question, input_digits)
    answer = str(a + b)
    answer = padding(answer, output_digits)
    
    added.add(pair)
    questions.append(question)
    answers.append(answer)

# %%
chars = '0123456789+ '
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
X = np.zeros((len(questions), input_digits, len(chars)), dtype=np.integer)
Y = np.zeros((len(questions), digits + 1, len(chars)), dtype=np.integer)

for i in range(N):
    for t, char in enumerate(questions[i]):
        X[i, t, char_indices[char]] = 1
    for t, char in enumerate(answers[i]):
        Y[i, t, char_indices[char]] = 1

X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, train_size=N_train)
# Out:
# /home/shimazu/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
def inference(x, y, n_batch, is_training,
              input_digits=None, output_digits=None,
              n_hidden=None, n_out=None):
    def weight_variable(shape):
        initial = tf.truncated_normal(shape, stddev=0.01)
        return tf.Variable(initial)

    def bias_variable(shape):
        initial = tf.zeros(shape, dtype=tf.float32)
        return tf.Variable(initial)

    # Encoder
    encoder = tf.contrib.rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)
    state = encoder.zero_state(n_batch, tf.float32)
    encoder_outputs = []
    encoder_states = []

    with tf.variable_scope('Encoder'):
        for t in range(input_digits):
            if t > 0:
                tf.get_variable_scope().reuse_variables()
            (output, state) = encoder(x[:, t, :], state)
            encoder_outputs.append(output)
            encoder_states.append(state)

    # Decoder
    decoder = tf.contrib.rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)
    state = encoder_states[-1]
    decoder_outputs = [encoder_outputs[-1]]

    # 出力層の重みとバイアスを事前に定義
    V = weight_variable([n_hidden, n_out])
    c = bias_variable([n_out])
    outputs = []

    with tf.variable_scope('Decoder'):
        for t in range(1, output_digits):
            if t > 1:
                tf.get_variable_scope().reuse_variables()

            if is_training is True:
                (output, state) = decoder(y[:, t-1, :], state)
            else:
                # 直前の出力を入力に用いる
                linear = tf.matmul(decoder_outputs[-1], V) + c
                out = tf.nn.softmax(linear)
                outputs.append(out)
                out = tf.one_hot(tf.argmax(out, -1), depth=output_digits)
                (output, state) = decoder(out, state)

            decoder_outputs.append(output)

    if is_training is True:
        output = tf.reshape(tf.concat(decoder_outputs, axis=1),
                            [-1, output_digits, n_hidden])

        linear = tf.einsum('ijk,kl->ijl', output, V) + c
        # linear = tf.matmul(output, V) + c
        return tf.nn.softmax(linear)
    else:
        # 最後の出力を求める
        linear = tf.matmul(decoder_outputs[-1], V) + c
        out = tf.nn.softmax(linear)
        outputs.append(out)

        output = tf.reshape(tf.concat(outputs, axis=1),
                            [-1, output_digits, n_out])
        return output

# %%
def loss(y, t):
    return tf.reduce_mean(tf.square(y-t))

def training(loss):
    optimizer = tf.train.AdamOptimizer(learning_rate=0.001, beta1=0.9, beta2=0.999)
    
    train_step = optimizer.minimize(loss)
    return train_step

# %%
def accuracy(y, t):
    correct_prediction = tf.equal(tf.argmax(y, -1), tf.argmax(t, -1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    return accuracy

# %%
n_in = len(chars)
n_hidden = 128
n_out = len(chars)

x = tf.placeholder(tf.float32, shape=[None, input_digits, n_in])
t = tf.placeholder(tf.float32, shape=[None, output_digits, n_out])
n_batch = tf.placeholder(tf.int32, shape=[])
is_training = tf.placeholder(tf.bool)

y = inference(x, t, n_batch, is_training,
                  input_digits=input_digits,
                  output_digits=output_digits,
                  n_hidden=n_hidden, n_out=n_out)
loss = loss(y, t)
train_step = training(loss)

acc = accuracy(y, t)
history = {
        'val_loss': [],
        'val_acc': []
    }

# %%
epochs = 200
batch_size = 200

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

n_batches = N_train // batch_size

# %%
for epoch in range(epochs):
    print('=' * 10)
    print('Epoch:', epoch)
    print('=' * 10)

    X_, Y_ = shuffle(X_train, Y_train)

    for i in range(n_batches):
        start = i * batch_size
        end = start + batch_size

        sess.run(train_step, feed_dict={
            x: X_[start:end],
            t: Y_[start:end],
            n_batch: batch_size,
            is_training: True
        })

    # 検証データを用いた評価
    val_loss = loss.eval(session=sess, feed_dict={
        x: X_validation,
        t: Y_validation,
        n_batch: N_validation,
        is_training: False
    })
    val_acc = acc.eval(session=sess, feed_dict={
        x: X_validation,
        t: Y_validation,
        n_batch: N_validation,
        is_training: False
    })

    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)
    print('validation loss:', val_loss)
    print('validation acc: ', val_acc)
# Out:
# ==========
# Epoch: 0
# ==========
# validation loss: 0.0593419
# validation acc:  0.3525
# ==========
# Epoch: 1
# ==========
# validation loss: 0.0581544
# validation acc:  0.352125
# ==========
# Epoch: 2
# ==========
# validation loss: 0.0578293
# validation acc:  0.3535
# ==========
# Epoch: 3
# ==========
# validation loss: 0.057663
# validation acc:  0.3575
# ==========
# Epoch: 4
# ==========
# validation loss: 0.0574567
# validation acc:  0.358375
# ==========
# Epoch: 5
# ==========
# validation loss: 0.0571819
# validation acc:  0.367375
# ==========
# Epoch: 6
# ==========
# validation loss: 0.0563238
# validation acc:  0.374625
# ==========
# Epoch: 7
# ==========
# validation loss: 0.0563065
# validation acc:  0.3775
# ==========
# Epoch: 8
# ==========
# validation loss: 0.0544865
# validation acc:  0.396375
# ==========
# Epoch: 9
# ==========
# validation loss: 0.0532548
# validation acc:  0.41225
# ==========
# Epoch: 10
# ==========
# validation loss: 0.0515745
# validation acc:  0.440375
# ==========
# Epoch: 11
# ==========
# validation loss: 0.0501383
# validation acc:  0.457875
# ==========
# Epoch: 12
# ==========
# validation loss: 0.0482513
# validation acc:  0.47475
# ==========
# Epoch: 13
# ==========
# validation loss: 0.0470425
# validation acc:  0.4855
# ==========
# Epoch: 14
# ==========
# validation loss: 0.0459659
# validation acc:  0.499625
# ==========
# Epoch: 15
# ==========
# validation loss: 0.0450718
# validation acc:  0.510375
# ==========
# Epoch: 16
# ==========
# validation loss: 0.0446638
# validation acc:  0.51675
# ==========
# Epoch: 17
# ==========
# validation loss: 0.043384
# validation acc:  0.530375
# ==========
# Epoch: 18
# ==========
# validation loss: 0.0429247
# validation acc:  0.5375
# ==========
# Epoch: 19
# ==========
# validation loss: 0.0422817
# validation acc:  0.546125
# ==========
# Epoch: 20
# ==========
# validation loss: 0.0416124
# validation acc:  0.552125
# ==========
# Epoch: 21
# ==========
# validation loss: 0.0414209
# validation acc:  0.5565
# ==========
# Epoch: 22
# ==========
# validation loss: 0.0409717
# validation acc:  0.5615
# ==========
# Epoch: 23
# ==========
# validation loss: 0.0400242
# validation acc:  0.570125
# ==========
# Epoch: 24
# ==========
# validation loss: 0.0397866
# validation acc:  0.570875
# ==========
# Epoch: 25
# ==========
# validation loss: 0.0388151
# validation acc:  0.585625
# ==========
# Epoch: 26
# ==========
# validation loss: 0.0385725
# validation acc:  0.585
# ==========
# Epoch: 27
# ==========
# validation loss: 0.0382298
# validation acc:  0.59025
# ==========
# Epoch: 28
# ==========
# validation loss: 0.0376655
# validation acc:  0.594125
# ==========
# Epoch: 29
# ==========
# validation loss: 0.0373575
# validation acc:  0.602375
# ==========
# Epoch: 30
# ==========
# validation loss: 0.0368513
# validation acc:  0.60325
# ==========
# Epoch: 31
# ==========
# validation loss: 0.037057
# validation acc:  0.601375
# ==========
# Epoch: 32
# ==========
# validation loss: 0.0368803
# validation acc:  0.603
# ==========
# Epoch: 33
# ==========
# validation loss: 0.0359651
# validation acc:  0.61475
# ==========
# Epoch: 34
# ==========
# validation loss: 0.0355452
# validation acc:  0.620375
# ==========
# Epoch: 35
# ==========
# validation loss: 0.0354571
# validation acc:  0.617125
# ==========
# Epoch: 36
# ==========
# validation loss: 0.034814
# validation acc:  0.627
# ==========
# Epoch: 37
# ==========
# validation loss: 0.0347808
# validation acc:  0.62775
# ==========
# Epoch: 38
# ==========
# validation loss: 0.0345427
# validation acc:  0.631625
# ==========
# Epoch: 39
# ==========
# validation loss: 0.0342043
# validation acc:  0.637375
# ==========
# Epoch: 40
# ==========
# validation loss: 0.0340007
# validation acc:  0.63525
# ==========
# Epoch: 41
# ==========
# validation loss: 0.0338749
# validation acc:  0.637875
# ==========
# Epoch: 42
# ==========
# validation loss: 0.0337452
# validation acc:  0.639875
# ==========
# Epoch: 43
# ==========
# validation loss: 0.0333615
# validation acc:  0.642625
# ==========
# Epoch: 44
# ==========
# validation loss: 0.0333553
# validation acc:  0.643
# ==========
# Epoch: 45
# ==========
# validation loss: 0.0330976
# validation acc:  0.652125
# ==========
# Epoch: 46
# ==========
# validation loss: 0.0326788
# validation acc:  0.651875
# ==========
# Epoch: 47
# ==========
# validation loss: 0.0326184
# validation acc:  0.6555
# ==========
# Epoch: 48
# ==========
# validation loss: 0.0323503
# validation acc:  0.659125
# ==========
# Epoch: 49
# ==========
# validation loss: 0.032557
# validation acc:  0.65975
# ==========
# Epoch: 50
# ==========
# validation loss: 0.0320207
# validation acc:  0.6635
# ==========
# Epoch: 51
# ==========
# validation loss: 0.0324503
# validation acc:  0.6585
# ==========
# Epoch: 52
# ==========
# validation loss: 0.031952
# validation acc:  0.6635
# ==========
# Epoch: 53
# ==========
# validation loss: 0.0317471
# validation acc:  0.668
# ==========
# Epoch: 54
# ==========
# validation loss: 0.0317218
# validation acc:  0.665125
# ==========
# Epoch: 55
# ==========
# validation loss: 0.031397
# validation acc:  0.6715
# ==========
# Epoch: 56
# ==========
# validation loss: 0.0314239
# validation acc:  0.671875
# ==========
# Epoch: 57
# ==========
# validation loss: 0.0311072
# validation acc:  0.676375
# ==========
# Epoch: 58
# ==========
# validation loss: 0.0308734
# validation acc:  0.68125
# ==========
# Epoch: 59
# ==========
# validation loss: 0.0309459
# validation acc:  0.680625
# ==========
# Epoch: 60
# ==========
# validation loss: 0.0307295
# validation acc:  0.681
# ==========
# Epoch: 61
# ==========
# validation loss: 0.0309916
# validation acc:  0.67725
# ==========
# Epoch: 62
# ==========
# validation loss: 0.0304588
# validation acc:  0.684375
# ==========
# Epoch: 63
# ==========
# validation loss: 0.030475
# validation acc:  0.683875
# ==========
# Epoch: 64
# ==========
# validation loss: 0.0304799
# validation acc:  0.68625
# ==========
# Epoch: 65
# ==========
# validation loss: 0.0302221
# validation acc:  0.6865
# ==========
# Epoch: 66
# ==========
# validation loss: 0.0299988
# validation acc:  0.69225
# ==========
# Epoch: 67
# ==========
# validation loss: 0.0297666
# validation acc:  0.695
# ==========
# Epoch: 68
# ==========
# validation loss: 0.0300237
# validation acc:  0.6935
# ==========
# Epoch: 69
# ==========
# validation loss: 0.0297873
# validation acc:  0.696375
# ==========
# Epoch: 70
# ==========
# validation loss: 0.0295441
# validation acc:  0.698625
# ==========
# Epoch: 71
# ==========
# validation loss: 0.0296537
# validation acc:  0.700625
# ==========
# Epoch: 72
# ==========
# validation loss: 0.0296013
# validation acc:  0.6995
# ==========
# Epoch: 73
# ==========
# validation loss: 0.029586
# validation acc:  0.700375
# ==========
# Epoch: 74
# ==========
# validation loss: 0.0292254
# validation acc:  0.707375
# ==========
# Epoch: 75
# ==========
# validation loss: 0.0292673
# validation acc:  0.709625
# ==========
# Epoch: 76
# ==========
# validation loss: 0.0292446
# validation acc:  0.7075
# ==========
# Epoch: 77
# ==========
# validation loss: 0.0291683
# validation acc:  0.708375
# ==========
# Epoch: 78
# ==========
# validation loss: 0.0288163
# validation acc:  0.713625
# ==========
# Epoch: 79
# ==========
# validation loss: 0.0289131
# validation acc:  0.713375
# ==========
# Epoch: 80
# ==========
# validation loss: 0.0286843
# validation acc:  0.713875
# ==========
# Epoch: 81
# ==========
# validation loss: 0.0288175
# validation acc:  0.71575
# ==========
# Epoch: 82
# ==========
# validation loss: 0.0286518
# validation acc:  0.71725
# ==========
# Epoch: 83
# ==========
# validation loss: 0.0284814
# validation acc:  0.7185
# ==========
# Epoch: 84
# ==========
# validation loss: 0.0283636
# validation acc:  0.723
# ==========
# Epoch: 85
# ==========
# validation loss: 0.0283504
# validation acc:  0.724125
# ==========
# Epoch: 86
# ==========
# validation loss: 0.0283294
# validation acc:  0.722375
# ==========
# Epoch: 87
# ==========
# validation loss: 0.0280671
# validation acc:  0.7285
# ==========
# Epoch: 88
# ==========
# validation loss: 0.0281155
# validation acc:  0.72875
# ==========
# Epoch: 89
# ==========
# validation loss: 0.0278143
# validation acc:  0.733625
# ==========
# Epoch: 90
# ==========
# validation loss: 0.0278628
# validation acc:  0.73375
# ==========
# Epoch: 91
# ==========
# validation loss: 0.0278335
# validation acc:  0.73325
# ==========
# Epoch: 92
# ==========
# validation loss: 0.0274766
# validation acc:  0.73675
# ==========
# Epoch: 93
# ==========
# validation loss: 0.0276355
# validation acc:  0.735125
# ==========
# Epoch: 94
# ==========
# validation loss: 0.0272573
# validation acc:  0.742625
# ==========
# Epoch: 95
# ==========
# validation loss: 0.0274525
# validation acc:  0.742
# ==========
# Epoch: 96
# ==========
# validation loss: 0.0270996
# validation acc:  0.74475
# ==========
# Epoch: 97
# ==========
# validation loss: 0.027019
# validation acc:  0.746625
# ==========
# Epoch: 98
# ==========
# validation loss: 0.0267438
# validation acc:  0.75075
# ==========
# Epoch: 99
# ==========
# validation loss: 0.026936
# validation acc:  0.748125
# ==========
# Epoch: 100
# ==========
# validation loss: 0.0267858
# validation acc:  0.75075
# ==========
# Epoch: 101
# ==========
# validation loss: 0.0269325
# validation acc:  0.752125
# ==========
# Epoch: 102
# ==========
# validation loss: 0.0266614
# validation acc:  0.7545
# ==========
# Epoch: 103
# ==========
# validation loss: 0.0265066
# validation acc:  0.751875
# ==========
# Epoch: 104
# ==========
# validation loss: 0.0266199
# validation acc:  0.756125
# ==========
# Epoch: 105
# ==========
# validation loss: 0.0262071
# validation acc:  0.759125
# ==========
# Epoch: 106
# ==========
# validation loss: 0.0261886
# validation acc:  0.756875
# ==========
# Epoch: 107
# ==========
# validation loss: 0.0261064
# validation acc:  0.76225
# ==========
# Epoch: 108
# ==========
# validation loss: 0.0261934
# validation acc:  0.763875
# ==========
# Epoch: 109
# ==========
# validation loss: 0.0261756
# validation acc:  0.763125
# ==========
# Epoch: 110
# ==========
# validation loss: 0.0262239
# validation acc:  0.764875
# ==========
# Epoch: 111
# ==========
# validation loss: 0.0258122
# validation acc:  0.76875
# ==========
# Epoch: 112
# ==========
# validation loss: 0.0255771
# validation acc:  0.769875
# ==========
# Epoch: 113
# ==========
# validation loss: 0.0257334
# validation acc:  0.77025
# ==========
# Epoch: 114
# ==========
# validation loss: 0.0258501
# validation acc:  0.76575
# ==========
# Epoch: 115
# ==========
# validation loss: 0.0255604
# validation acc:  0.77375
# ==========
# Epoch: 116
# ==========
# validation loss: 0.025431
# validation acc:  0.77475
# ==========
# Epoch: 117
# ==========
# validation loss: 0.0256953
# validation acc:  0.769625
# ==========
# Epoch: 118
# ==========
# validation loss: 0.0253959
# validation acc:  0.771625
# ==========
# Epoch: 119
# ==========
# validation loss: 0.0254552
# validation acc:  0.7745
# ==========
# Epoch: 120
# ==========
# validation loss: 0.0252171
# validation acc:  0.774375
# ==========
# Epoch: 121
# ==========
# validation loss: 0.0249293
# validation acc:  0.777625
# ==========
# Epoch: 122
# ==========
# validation loss: 0.0252985
# validation acc:  0.775375
# ==========
# Epoch: 123
# ==========
# validation loss: 0.0252051
# validation acc:  0.77875
# ==========
# Epoch: 124
# ==========
# validation loss: 0.0250478
# validation acc:  0.780625
# ==========
# Epoch: 125
# ==========
# validation loss: 0.0248828
# validation acc:  0.78025
# ==========
# Epoch: 126
# ==========
# validation loss: 0.0251101
# validation acc:  0.782125
# ==========
# Epoch: 127
# ==========
# validation loss: 0.025011
# validation acc:  0.783375
# ==========
# Epoch: 128
# ==========
# validation loss: 0.0246169
# validation acc:  0.786
# ==========
# Epoch: 129
# ==========
# validation loss: 0.0249825
# validation acc:  0.786125
# ==========
# Epoch: 130
# ==========
# validation loss: 0.0251878
# validation acc:  0.78475
# ==========
# Epoch: 131
# ==========
# validation loss: 0.0246555
# validation acc:  0.787125
# ==========
# Epoch: 132
# ==========
# validation loss: 0.0248913
# validation acc:  0.78525
# ==========
# Epoch: 133
# ==========
# validation loss: 0.0251106
# validation acc:  0.785625
# ==========
# Epoch: 134
# ==========
# validation loss: 0.0245478
# validation acc:  0.79025
# ==========
# Epoch: 135
# ==========
# validation loss: 0.024762
# validation acc:  0.78875
# ==========
# Epoch: 136
# ==========
# validation loss: 0.0247568
# validation acc:  0.78875
# ==========
# Epoch: 137
# ==========
# validation loss: 0.0244614
# validation acc:  0.792875
# ==========
# Epoch: 138
# ==========
# validation loss: 0.0246455
# validation acc:  0.7905
# ==========
# Epoch: 139
# ==========
# validation loss: 0.0245721
# validation acc:  0.792375
# ==========
# Epoch: 140
# ==========
# validation loss: 0.0246384
# validation acc:  0.792625
# ==========
# Epoch: 141
# ==========
# validation loss: 0.0245337
# validation acc:  0.791875
# ==========
# Epoch: 142
# ==========
# validation loss: 0.0242509
# validation acc:  0.795875
# ==========
# Epoch: 143
# ==========
# validation loss: 0.0243634
# validation acc:  0.793875
# ==========
# Epoch: 144
# ==========
# validation loss: 0.0247766
# validation acc:  0.792375
# ==========
# Epoch: 145
# ==========
# validation loss: 0.0246141
# validation acc:  0.7935
# ==========
# Epoch: 146
# ==========
# validation loss: 0.0249591
# validation acc:  0.793
# ==========
# Epoch: 147
# ==========
# validation loss: 0.0244312
# validation acc:  0.794875
# ==========
# Epoch: 148
# ==========
# validation loss: 0.0245907
# validation acc:  0.79675
# ==========
# Epoch: 149
# ==========
# validation loss: 0.0246588
# validation acc:  0.795
# ==========
# Epoch: 150
# ==========
# validation loss: 0.0244132
# validation acc:  0.79725
# ==========
# Epoch: 151
# ==========
# validation loss: 0.0247104
# validation acc:  0.794375
# ==========
# Epoch: 152
# ==========
# validation loss: 0.0249755
# validation acc:  0.79175
# ==========
# Epoch: 153
# ==========
# validation loss: 0.0246545
# validation acc:  0.79425
# ==========
# Epoch: 154
# ==========
# validation loss: 0.0248244
# validation acc:  0.795125
# ==========
# Epoch: 155
# ==========
# validation loss: 0.0244396
# validation acc:  0.797125
# ==========
# Epoch: 156
# ==========
# validation loss: 0.0245831
# validation acc:  0.796375
# ==========
# Epoch: 157
# ==========
# validation loss: 0.0247625
# validation acc:  0.7925
# ==========
# Epoch: 158
# ==========
# validation loss: 0.0249269
# validation acc:  0.79375
# ==========
# Epoch: 159
# ==========
# validation loss: 0.0246076
# validation acc:  0.7975
# ==========
# Epoch: 160
# ==========
# validation loss: 0.0245929
# validation acc:  0.800125
# ==========
# Epoch: 161
# ==========
# validation loss: 0.0245563
# validation acc:  0.7945
# ==========
# Epoch: 162
# ==========
# validation loss: 0.0247567
# validation acc:  0.797
# ==========
# Epoch: 163
# ==========
# validation loss: 0.0248933
# validation acc:  0.7965
# ==========
# Epoch: 164
# ==========
# validation loss: 0.0247166
# validation acc:  0.798125
# ==========
# Epoch: 165
# ==========
# validation loss: 0.0250667
# validation acc:  0.794625
# ==========
# Epoch: 166
# ==========
# validation loss: 0.024639
# validation acc:  0.8
# ==========
# Epoch: 167
# ==========
# validation loss: 0.0249197
# validation acc:  0.79525
# ==========
# Epoch: 168
# ==========
# validation loss: 0.025314
# validation acc:  0.79525
# ==========
# Epoch: 169
# ==========
# validation loss: 0.0249851
# validation acc:  0.79725
# ==========
# Epoch: 170
# ==========
# validation loss: 0.0247691
# validation acc:  0.7995
# ==========
# Epoch: 171
# ==========
# validation loss: 0.0249535
# validation acc:  0.798375
# ==========
# Epoch: 172
# ==========
# validation loss: 0.0249164
# validation acc:  0.799875
# ==========
# Epoch: 173
# ==========
# validation loss: 0.025447
# validation acc:  0.793875
# ==========
# Epoch: 174
# ==========
# validation loss: 0.0259778
# validation acc:  0.79075
# ==========
# Epoch: 175
# ==========
# validation loss: 0.0257403
# validation acc:  0.7925
# ==========
# Epoch: 176
# ==========
# validation loss: 0.0248834
# validation acc:  0.799125
# ==========
# Epoch: 177
# ==========
# validation loss: 0.0247338
# validation acc:  0.802625
# ==========
# Epoch: 178
# ==========
# validation loss: 0.0249651
# validation acc:  0.796125
# ==========
# Epoch: 179
# ==========
# validation loss: 0.024871
# validation acc:  0.798125
# ==========
# Epoch: 180
# ==========
# validation loss: 0.0248901
# validation acc:  0.799875
# ==========
# Epoch: 181
# ==========
# validation loss: 0.0250585
# validation acc:  0.798
# ==========
# Epoch: 182
# ==========
# validation loss: 0.0252287
# validation acc:  0.796
# ==========
# Epoch: 183
# ==========
# validation loss: 0.025693
# validation acc:  0.794
# ==========
# Epoch: 184
# ==========
# validation loss: 0.0254418
# validation acc:  0.797
# ==========
# Epoch: 185
# ==========
# validation loss: 0.0254989
# validation acc:  0.796
# ==========
# Epoch: 186
# ==========
# validation loss: 0.0251745
# validation acc:  0.799125
# ==========
# Epoch: 187
# ==========
# validation loss: 0.0250378
# validation acc:  0.796625
# ==========
# Epoch: 188
# ==========
# validation loss: 0.0252361
# validation acc:  0.79925
# ==========
# Epoch: 189
# ==========
# validation loss: 0.0253408
# validation acc:  0.8
# ==========
# Epoch: 190
# ==========
# validation loss: 0.0253009
# validation acc:  0.797875
# ==========
# Epoch: 191
# ==========
# validation loss: 0.0253731
# validation acc:  0.797375
# ==========
# Epoch: 192
# ==========
# validation loss: 0.0255629
# validation acc:  0.7945
# ==========
# Epoch: 193
# ==========
# validation loss: 0.0257129
# validation acc:  0.795875
# ==========
# Epoch: 194
# ==========
# validation loss: 0.0268272
# validation acc:  0.787
# ==========
# Epoch: 195
# ==========
# validation loss: 0.026625
# validation acc:  0.789
# ==========
# Epoch: 196
# ==========
# validation loss: 0.0258729
# validation acc:  0.794375
# ==========
# Epoch: 197
# ==========
# validation loss: 0.0255101
# validation acc:  0.79775
# ==========
# Epoch: 198
# ==========
# validation loss: 0.0251527
# validation acc:  0.80025
# ==========
# Epoch: 199
# ==========
# validation loss: 0.0250423
# validation acc:  0.802625

# %%
# 検証データからランダムに問題を選んで答え合わせ
for i in range(10):
    index = np.random.randint(0, N_validation)
    question = X_validation[np.array([index])]
    answer = Y_validation[np.array([index])]
    prediction = y.eval(session=sess, feed_dict={
        x: question,
        # t: answer,
        n_batch: 1,
        is_training: False
    })
    question = question.argmax(axis=-1)
    answer = answer.argmax(axis=-1)
    prediction = np.argmax(prediction, -1)

    q = ''.join(indices_char[i] for i in question[0])
    a = ''.join(indices_char[i] for i in answer[0])
    p = ''.join(indices_char[i] for i in prediction[0])

    print('-' * 10)
    print('Q:  ', q)
    print('A:  ', p)
    print('T/F:', end=' ')
    if a == p:
        print('T')
    else:
        print('F')
print('-' * 10)
# Out:
# ----------
# Q:   549+975
# A:   1521
# T/F: F
# ----------
# Q:   40+26
# A:   66
# T/F: T
# ----------
# Q:   66+413
# A:   479
# T/F: T
# ----------
# Q:   46+1
# A:   47
# T/F: T
# ----------
# Q:   530+1
# A:   531
# T/F: T
# ----------
# Q:   92+46
# A:   138
# T/F: T
# ----------
# Q:   0+66
# A:   66
# T/F: T
# ----------
# Q:   0+868
# A:   868
# T/F: T
# ----------
# Q:   916+364
# A:   1301
# T/F: F
# ----------
# Q:   302+5
# A:   306
# T/F: F
# ----------

# %% [markdown]
# # Kerasによる実装

# %%
from keras.optimizers import Adam
from keras.layers import Activation, Dense
from keras.layers.core import RepeatVector
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import TimeDistributed
from keras.models import Sequential

# %%
model = Sequential()

# Encoder
model.add(LSTM(n_hidden, input_shape=(input_digits, n_in)))

# Decoder
model.add(RepeatVector(output_digits))
model.add(LSTM(n_hidden, return_sequences=True))
model.add(TimeDistributed(Dense(n_out)))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy',
             optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
             metrics=['accuracy'])

# %%
epochs = 200
batch_size = 200

for epoch in range(epochs):
    model.fit(X_train, Y_train, batch_size=batch_size, epochs=1,
              validation_data=(X_validation, Y_validation))

    # 検証データからランダムに問題を選んで答え合わせ
    for i in range(10):
        index = np.random.randint(0, N_validation)
        question = X_validation[np.array([index])]
        answer = Y_validation[np.array([index])]
        prediction = model.predict_classes(question, verbose=0)

        question = question.argmax(axis=-1)
        answer = answer.argmax(axis=-1)

        q = ''.join(indices_char[i] for i in question[0])
        a = ''.join(indices_char[i] for i in answer[0])
        p = ''.join(indices_char[i] for i in prediction[0])

        print('-' * 10)
        print('Q:  ', q)
        print('A:  ', p)
        print('T/F:', end=' ')
        if a == p:
            print('T')
        else:
            print('F')
    print('-' * 10)
# Out:
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 363us/step - loss: 2.0353 - acc: 0.2884 - val_loss: 1.8333 - val_acc: 0.3511
# ----------
# Q:   54+641
# A:   110
# T/F: F
# ----------
# Q:   81+823
# A:   110
# T/F: F
# ----------
# Q:   21+654
# A:   119
# T/F: F
# ----------
# Q:   362+28
# A:   110
# T/F: F
# ----------
# Q:   6+181
# A:   11
# T/F: F
# ----------
# Q:   23+869
# A:   110
# T/F: F
# ----------
# Q:   73+760
# A:   110
# T/F: F
# ----------
# Q:   2+485
# A:   119
# T/F: F
# ----------
# Q:   95+546
# A:   110
# T/F: F
# ----------
# Q:   312+6
# A:   11
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 329us/step - loss: 1.7957 - acc: 0.3503 - val_loss: 1.7769 - val_acc: 0.3570
# ----------
# Q:   578+70
# A:   119
# T/F: F
# ----------
# Q:   751+6
# A:   12
# T/F: F
# ----------
# Q:   123+829
# A:   119
# T/F: F
# ----------
# Q:   53+526
# A:   139
# T/F: F
# ----------
# Q:   853+667
# A:   110
# T/F: F
# ----------
# Q:   44+200
# A:   139
# T/F: F
# ----------
# Q:   601+2
# A:   12
# T/F: F
# ----------
# Q:   14+44
# A:   14
# T/F: F
# ----------
# Q:   546+4
# A:   14
# T/F: F
# ----------
# Q:   31+134
# A:   133
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 1.7722 - acc: 0.3572 - val_loss: 1.7628 - val_acc: 0.3548
# ----------
# Q:   93+54
# A:   109
# T/F: F
# ----------
# Q:   619+992
# A:   100
# T/F: F
# ----------
# Q:   85+63
# A:   10
# T/F: F
# ----------
# Q:   5+825
# A:   10
# T/F: F
# ----------
# Q:   909+678
# A:   1001
# T/F: F
# ----------
# Q:   9+62
# A:   10
# T/F: F
# ----------
# Q:   474+751
# A:   110
# T/F: F
# ----------
# Q:   749+69
# A:   100
# T/F: F
# ----------
# Q:   0+862
# A:   10
# T/F: F
# ----------
# Q:   788+389
# A:   100
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 342us/step - loss: 1.7526 - acc: 0.3577 - val_loss: 1.7436 - val_acc: 0.3574
# ----------
# Q:   29+87
# A:   102
# T/F: F
# ----------
# Q:   823+921
# A:   103
# T/F: F
# ----------
# Q:   20+30
# A:   32
# T/F: F
# ----------
# Q:   547+79
# A:   107
# T/F: F
# ----------
# Q:   416+2
# A:   13
# T/F: F
# ----------
# Q:   19+711
# A:   101
# T/F: F
# ----------
# Q:   117+0
# A:   11
# T/F: F
# ----------
# Q:   73+886
# A:   107
# T/F: F
# ----------
# Q:   4+274
# A:   13
# T/F: F
# ----------
# Q:   6+863
# A:   167
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 333us/step - loss: 1.7369 - acc: 0.3609 - val_loss: 1.7264 - val_acc: 0.3636
# ----------
# Q:   898+7
# A:   181
# T/F: F
# ----------
# Q:   72+380
# A:   111
# T/F: F
# ----------
# Q:   51+53
# A:   34
# T/F: F
# ----------
# Q:   320+69
# A:   111
# T/F: F
# ----------
# Q:   154+169
# A:   115
# T/F: F
# ----------
# Q:   94+45
# A:   155
# T/F: F
# ----------
# Q:   7+159
# A:   19
# T/F: F
# ----------
# Q:   909+678
# A:   1081
# T/F: F
# ----------
# Q:   99+971
# A:   101
# T/F: F
# ----------
# Q:   183+761
# A:   101
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 322us/step - loss: 1.7157 - acc: 0.3662 - val_loss: 1.7044 - val_acc: 0.3683
# ----------
# Q:   44+566
# A:   544
# T/F: F
# ----------
# Q:   8+268
# A:   101
# T/F: F
# ----------
# Q:   168+280
# A:   102
# T/F: F
# ----------
# Q:   66+155
# A:   144
# T/F: F
# ----------
# Q:   542+198
# A:   102
# T/F: F
# ----------
# Q:   97+32
# A:   101
# T/F: F
# ----------
# Q:   970+319
# A:   102
# T/F: F
# ----------
# Q:   553+552
# A:   154
# T/F: F
# ----------
# Q:   49+55
# A:   545
# T/F: F
# ----------
# Q:   2+244
# A:   34
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 323us/step - loss: 1.6903 - acc: 0.3734 - val_loss: 1.6744 - val_acc: 0.3804
# ----------
# Q:   765+566
# A:   1562
# T/F: F
# ----------
# Q:   80+56
# A:   165
# T/F: F
# ----------
# Q:   8+768
# A:   886
# T/F: F
# ----------
# Q:   123+875
# A:   118
# T/F: F
# ----------
# Q:   10+523
# A:   315
# T/F: F
# ----------
# Q:   2+800
# A:   111
# T/F: F
# ----------
# Q:   222+0
# A:   222
# T/F: T
# ----------
# Q:   497+925
# A:   1011
# T/F: F
# ----------
# Q:   648+21
# A:   108
# T/F: F
# ----------
# Q:   392+634
# A:   100
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 324us/step - loss: 1.6612 - acc: 0.3862 - val_loss: 1.6544 - val_acc: 0.3920
# ----------
# Q:   21+377
# A:   228
# T/F: F
# ----------
# Q:   82+23
# A:   22
# T/F: F
# ----------
# Q:   6+181
# A:   11
# T/F: F
# ----------
# Q:   970+36
# A:   106
# T/F: F
# ----------
# Q:   24+339
# A:   334
# T/F: F
# ----------
# Q:   448+270
# A:   111
# T/F: F
# ----------
# Q:   329+902
# A:   113
# T/F: F
# ----------
# Q:   7+763
# A:   776
# T/F: F
# ----------
# Q:   854+2
# A:   66
# T/F: F
# ----------
# Q:   271+4
# A:   22
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 323us/step - loss: 1.6266 - acc: 0.3989 - val_loss: 1.6080 - val_acc: 0.4055
# ----------
# Q:   4+589
# A:   550
# T/F: F
# ----------
# Q:   174+42
# A:   577
# T/F: F
# ----------
# Q:   19+30
# A:   13
# T/F: F
# ----------
# Q:   543+883
# A:   1100
# T/F: F
# ----------
# Q:   358+925
# A:   1007
# T/F: F
# ----------
# Q:   99+27
# A:   900
# T/F: F
# ----------
# Q:   6+623
# A:   67
# T/F: F
# ----------
# Q:   7+959
# A:   105
# T/F: F
# ----------
# Q:   2+530
# A:   45
# T/F: F
# ----------
# Q:   36+81
# A:   137
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 337us/step - loss: 1.5905 - acc: 0.4121 - val_loss: 1.5773 - val_acc: 0.4143
# ----------
# Q:   34+768
# A:   708
# T/F: F
# ----------
# Q:   7+774
# A:   774
# T/F: F
# ----------
# Q:   90+398
# A:   903
# T/F: F
# ----------
# Q:   3+989
# A:   100
# T/F: F
# ----------
# Q:   71+399
# A:   101
# T/F: F
# ----------
# Q:   36+496
# A:   408
# T/F: F
# ----------
# Q:   854+80
# A:   855
# T/F: F
# ----------
# Q:   780+279
# A:   108
# T/F: F
# ----------
# Q:   92+93
# A:   902
# T/F: F
# ----------
# Q:   549+975
# A:   1403
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 1.5540 - acc: 0.4235 - val_loss: 1.5438 - val_acc: 0.4260
# ----------
# Q:   0+679
# A:   764
# T/F: F
# ----------
# Q:   90+41
# A:   105
# T/F: F
# ----------
# Q:   775+2
# A:   778
# T/F: F
# ----------
# Q:   7+756
# A:   774
# T/F: F
# ----------
# Q:   731+36
# A:   707
# T/F: F
# ----------
# Q:   0+868
# A:   886
# T/F: F
# ----------
# Q:   141+903
# A:   100
# T/F: F
# ----------
# Q:   684+0
# A:   155
# T/F: F
# ----------
# Q:   961+89
# A:   106
# T/F: F
# ----------
# Q:   843+0
# A:   941
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 336us/step - loss: 1.5226 - acc: 0.4349 - val_loss: 1.5100 - val_acc: 0.4366
# ----------
# Q:   870+57
# A:   858
# T/F: F
# ----------
# Q:   0+397
# A:   301
# T/F: F
# ----------
# Q:   312+6
# A:   338
# T/F: F
# ----------
# Q:   221+5
# A:   228
# T/F: F
# ----------
# Q:   0+10
# A:   11
# T/F: F
# ----------
# Q:   0+77
# A:   77
# T/F: T
# ----------
# Q:   0+590
# A:   505
# T/F: F
# ----------
# Q:   80+4
# A:   10
# T/F: F
# ----------
# Q:   21+231
# A:   234
# T/F: F
# ----------
# Q:   105+45
# A:   551
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 340us/step - loss: 1.4789 - acc: 0.4511 - val_loss: 1.4679 - val_acc: 0.4519
# ----------
# Q:   3+355
# A:   33
# T/F: F
# ----------
# Q:   959+4
# A:   993
# T/F: F
# ----------
# Q:   86+319
# A:   331
# T/F: F
# ----------
# Q:   744+617
# A:   1113
# T/F: F
# ----------
# Q:   815+74
# A:   853
# T/F: F
# ----------
# Q:   60+889
# A:   886
# T/F: F
# ----------
# Q:   54+107
# A:   554
# T/F: F
# ----------
# Q:   72+380
# A:   800
# T/F: F
# ----------
# Q:   146+8
# A:   113
# T/F: F
# ----------
# Q:   546+88
# A:   523
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 1.4254 - acc: 0.4723 - val_loss: 1.4194 - val_acc: 0.4719
# ----------
# Q:   137+39
# A:   355
# T/F: F
# ----------
# Q:   309+54
# A:   443
# T/F: F
# ----------
# Q:   211+40
# A:   224
# T/F: F
# ----------
# Q:   904+18
# A:   901
# T/F: F
# ----------
# Q:   749+64
# A:   700
# T/F: F
# ----------
# Q:   962+341
# A:   1313
# T/F: F
# ----------
# Q:   1+850
# A:   855
# T/F: F
# ----------
# Q:   28+431
# A:   451
# T/F: F
# ----------
# Q:   664+60
# A:   640
# T/F: F
# ----------
# Q:   804+2
# A:   832
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 329us/step - loss: 1.3808 - acc: 0.4891 - val_loss: 1.3716 - val_acc: 0.4885
# ----------
# Q:   373+0
# A:   377
# T/F: F
# ----------
# Q:   94+46
# A:   143
# T/F: F
# ----------
# Q:   415+3
# A:   458
# T/F: F
# ----------
# Q:   77+808
# A:   888
# T/F: F
# ----------
# Q:   23+24
# A:   33
# T/F: F
# ----------
# Q:   348+4
# A:   448
# T/F: F
# ----------
# Q:   5+899
# A:   986
# T/F: F
# ----------
# Q:   37+208
# A:   380
# T/F: F
# ----------
# Q:   120+222
# A:   254
# T/F: F
# ----------
# Q:   659+635
# A:   1364
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 333us/step - loss: 1.3285 - acc: 0.5096 - val_loss: 1.3258 - val_acc: 0.5095
# ----------
# Q:   72+942
# A:   102
# T/F: F
# ----------
# Q:   200+210
# A:   210
# T/F: F
# ----------
# Q:   903+71
# A:   901
# T/F: F
# ----------
# Q:   853+667
# A:   1510
# T/F: F
# ----------
# Q:   364+5
# A:   477
# T/F: F
# ----------
# Q:   543+8
# A:   552
# T/F: F
# ----------
# Q:   494+32
# A:   487
# T/F: F
# ----------
# Q:   745+415
# A:   1117
# T/F: F
# ----------
# Q:   171+51
# A:   272
# T/F: F
# ----------
# Q:   16+621
# A:   638
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 329us/step - loss: 1.2824 - acc: 0.5265 - val_loss: 1.2808 - val_acc: 0.5200
# ----------
# Q:   856+2
# A:   851
# T/F: F
# ----------
# Q:   5+748
# A:   751
# T/F: F
# ----------
# Q:   949+88
# A:   1042
# T/F: F
# ----------
# Q:   679+42
# A:   792
# T/F: F
# ----------
# Q:   3+998
# A:   108
# T/F: F
# ----------
# Q:   68+637
# A:   684
# T/F: F
# ----------
# Q:   9+19
# A:   29
# T/F: F
# ----------
# Q:   49+75
# A:   112
# T/F: F
# ----------
# Q:   29+4
# A:   49
# T/F: F
# ----------
# Q:   213+3
# A:   223
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 336us/step - loss: 1.2363 - acc: 0.5443 - val_loss: 1.2397 - val_acc: 0.5380
# ----------
# Q:   93+239
# A:   322
# T/F: F
# ----------
# Q:   223+1
# A:   222
# T/F: F
# ----------
# Q:   8+625
# A:   624
# T/F: F
# ----------
# Q:   95+65
# A:   164
# T/F: F
# ----------
# Q:   561+916
# A:   1515
# T/F: F
# ----------
# Q:   40+92
# A:   103
# T/F: F
# ----------
# Q:   877+283
# A:   1280
# T/F: F
# ----------
# Q:   90+9
# A:   10
# T/F: F
# ----------
# Q:   577+0
# A:   577
# T/F: T
# ----------
# Q:   30+350
# A:   377
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 1.1976 - acc: 0.5591 - val_loss: 1.2089 - val_acc: 0.5539
# ----------
# Q:   2+128
# A:   220
# T/F: F
# ----------
# Q:   23+177
# A:   184
# T/F: F
# ----------
# Q:   50+517
# A:   566
# T/F: F
# ----------
# Q:   10+5
# A:   56
# T/F: F
# ----------
# Q:   7+756
# A:   761
# T/F: F
# ----------
# Q:   846+244
# A:   1117
# T/F: F
# ----------
# Q:   473+65
# A:   501
# T/F: F
# ----------
# Q:   66+155
# A:   230
# T/F: F
# ----------
# Q:   8+585
# A:   586
# T/F: F
# ----------
# Q:   70+76
# A:   144
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 1.1602 - acc: 0.5730 - val_loss: 1.2250 - val_acc: 0.5420
# ----------
# Q:   856+3
# A:   861
# T/F: F
# ----------
# Q:   24+456
# A:   488
# T/F: F
# ----------
# Q:   406+4
# A:   411
# T/F: F
# ----------
# Q:   65+888
# A:   962
# T/F: F
# ----------
# Q:   58+74
# A:   141
# T/F: F
# ----------
# Q:   451+261
# A:   506
# T/F: F
# ----------
# Q:   542+48
# A:   596
# T/F: F
# ----------
# Q:   199+90
# A:   399
# T/F: F
# ----------
# Q:   39+476
# A:   421
# T/F: F
# ----------
# Q:   526+0
# A:   526
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 326us/step - loss: 1.1210 - acc: 0.5866 - val_loss: 1.1219 - val_acc: 0.5851
# ----------
# Q:   8+25
# A:   28
# T/F: F
# ----------
# Q:   619+137
# A:   799
# T/F: F
# ----------
# Q:   5+932
# A:   936
# T/F: F
# ----------
# Q:   920+100
# A:   1001
# T/F: F
# ----------
# Q:   50+301
# A:   491
# T/F: F
# ----------
# Q:   6+333
# A:   338
# T/F: F
# ----------
# Q:   677+135
# A:   809
# T/F: F
# ----------
# Q:   611+43
# A:   664
# T/F: F
# ----------
# Q:   1+293
# A:   299
# T/F: F
# ----------
# Q:   893+8
# A:   983
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 1.0805 - acc: 0.6004 - val_loss: 1.0844 - val_acc: 0.5944
# ----------
# Q:   7+640
# A:   644
# T/F: F
# ----------
# Q:   472+311
# A:   792
# T/F: F
# ----------
# Q:   473+65
# A:   501
# T/F: F
# ----------
# Q:   749+64
# A:   700
# T/F: F
# ----------
# Q:   43+168
# A:   189
# T/F: F
# ----------
# Q:   648+806
# A:   1498
# T/F: F
# ----------
# Q:   840+339
# A:   1132
# T/F: F
# ----------
# Q:   35+159
# A:   281
# T/F: F
# ----------
# Q:   64+834
# A:   899
# T/F: F
# ----------
# Q:   962+20
# A:   994
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 1.0410 - acc: 0.6135 - val_loss: 1.0497 - val_acc: 0.6020
# ----------
# Q:   797+632
# A:   1422
# T/F: F
# ----------
# Q:   149+4
# A:   150
# T/F: F
# ----------
# Q:   94+46
# A:   143
# T/F: F
# ----------
# Q:   119+18
# A:   229
# T/F: F
# ----------
# Q:   490+443
# A:   903
# T/F: F
# ----------
# Q:   120+821
# A:   901
# T/F: F
# ----------
# Q:   448+557
# A:   1023
# T/F: F
# ----------
# Q:   4+465
# A:   469
# T/F: T
# ----------
# Q:   453+789
# A:   1314
# T/F: F
# ----------
# Q:   6+973
# A:   980
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 326us/step - loss: 1.0041 - acc: 0.6275 - val_loss: 1.0113 - val_acc: 0.6160
# ----------
# Q:   74+53
# A:   128
# T/F: F
# ----------
# Q:   21+379
# A:   399
# T/F: F
# ----------
# Q:   222+9
# A:   221
# T/F: F
# ----------
# Q:   9+232
# A:   231
# T/F: F
# ----------
# Q:   21+27
# A:   39
# T/F: F
# ----------
# Q:   688+77
# A:   765
# T/F: T
# ----------
# Q:   279+945
# A:   1133
# T/F: F
# ----------
# Q:   834+404
# A:   1244
# T/F: F
# ----------
# Q:   546+4
# A:   569
# T/F: F
# ----------
# Q:   95+675
# A:   762
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 330us/step - loss: 0.9618 - acc: 0.6411 - val_loss: 0.9739 - val_acc: 0.6309
# ----------
# Q:   10+610
# A:   510
# T/F: F
# ----------
# Q:   892+39
# A:   900
# T/F: F
# ----------
# Q:   75+12
# A:   87
# T/F: T
# ----------
# Q:   29+87
# A:   116
# T/F: T
# ----------
# Q:   599+186
# A:   677
# T/F: F
# ----------
# Q:   97+9
# A:   107
# T/F: F
# ----------
# Q:   570+8
# A:   588
# T/F: F
# ----------
# Q:   584+8
# A:   582
# T/F: F
# ----------
# Q:   1+63
# A:   67
# T/F: F
# ----------
# Q:   506+82
# A:   670
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 0.9198 - acc: 0.6563 - val_loss: 0.9269 - val_acc: 0.6449
# ----------
# Q:   711+5
# A:   715
# T/F: F
# ----------
# Q:   127+86
# A:   244
# T/F: F
# ----------
# Q:   933+868
# A:   1814
# T/F: F
# ----------
# Q:   842+713
# A:   1564
# T/F: F
# ----------
# Q:   29+774
# A:   891
# T/F: F
# ----------
# Q:   4+754
# A:   758
# T/F: T
# ----------
# Q:   1+380
# A:   301
# T/F: F
# ----------
# Q:   54+641
# A:   697
# T/F: F
# ----------
# Q:   184+5
# A:   189
# T/F: T
# ----------
# Q:   31+22
# A:   33
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.8791 - acc: 0.6716 - val_loss: 0.8926 - val_acc: 0.6615
# ----------
# Q:   788+140
# A:   108
# T/F: F
# ----------
# Q:   258+9
# A:   266
# T/F: F
# ----------
# Q:   9+634
# A:   642
# T/F: F
# ----------
# Q:   691+1
# A:   692
# T/F: T
# ----------
# Q:   23+14
# A:   47
# T/F: F
# ----------
# Q:   977+26
# A:   1022
# T/F: F
# ----------
# Q:   42+282
# A:   312
# T/F: F
# ----------
# Q:   4+608
# A:   606
# T/F: F
# ----------
# Q:   91+78
# A:   169
# T/F: T
# ----------
# Q:   2+364
# A:   367
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 329us/step - loss: 0.8351 - acc: 0.6896 - val_loss: 0.8538 - val_acc: 0.6719
# ----------
# Q:   139+9
# A:   138
# T/F: F
# ----------
# Q:   28+5
# A:   52
# T/F: F
# ----------
# Q:   806+8
# A:   813
# T/F: F
# ----------
# Q:   492+221
# A:   733
# T/F: F
# ----------
# Q:   60+89
# A:   158
# T/F: F
# ----------
# Q:   9+780
# A:   788
# T/F: F
# ----------
# Q:   891+259
# A:   1270
# T/F: F
# ----------
# Q:   67+257
# A:   333
# T/F: F
# ----------
# Q:   462+52
# A:   594
# T/F: F
# ----------
# Q:   951+77
# A:   1036
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 326us/step - loss: 0.7919 - acc: 0.7051 - val_loss: 0.8124 - val_acc: 0.6830
# ----------
# Q:   48+93
# A:   132
# T/F: F
# ----------
# Q:   795+50
# A:   800
# T/F: F
# ----------
# Q:   557+988
# A:   1544
# T/F: F
# ----------
# Q:   58+120
# A:   179
# T/F: F
# ----------
# Q:   4+107
# A:   110
# T/F: F
# ----------
# Q:   103+7
# A:   108
# T/F: F
# ----------
# Q:   475+10
# A:   477
# T/F: F
# ----------
# Q:   82+105
# A:   214
# T/F: F
# ----------
# Q:   107+63
# A:   171
# T/F: F
# ----------
# Q:   291+587
# A:   978
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.7512 - acc: 0.7209 - val_loss: 0.7753 - val_acc: 0.6991
# ----------
# Q:   59+615
# A:   672
# T/F: F
# ----------
# Q:   39+49
# A:   97
# T/F: F
# ----------
# Q:   261+32
# A:   273
# T/F: F
# ----------
# Q:   479+471
# A:   901
# T/F: F
# ----------
# Q:   231+0
# A:   222
# T/F: F
# ----------
# Q:   227+1
# A:   228
# T/F: T
# ----------
# Q:   360+343
# A:   735
# T/F: F
# ----------
# Q:   867+3
# A:   890
# T/F: F
# ----------
# Q:   55+105
# A:   100
# T/F: F
# ----------
# Q:   729+38
# A:   766
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 331us/step - loss: 0.7075 - acc: 0.7399 - val_loss: 0.7369 - val_acc: 0.7131
# ----------
# Q:   207+89
# A:   287
# T/F: F
# ----------
# Q:   69+6
# A:   64
# T/F: F
# ----------
# Q:   19+923
# A:   932
# T/F: F
# ----------
# Q:   500+884
# A:   1387
# T/F: F
# ----------
# Q:   929+34
# A:   973
# T/F: F
# ----------
# Q:   817+8
# A:   826
# T/F: F
# ----------
# Q:   9+827
# A:   836
# T/F: T
# ----------
# Q:   93+445
# A:   548
# T/F: F
# ----------
# Q:   31+298
# A:   310
# T/F: F
# ----------
# Q:   86+319
# A:   306
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 0.6685 - acc: 0.7566 - val_loss: 0.6977 - val_acc: 0.7370
# ----------
# Q:   78+450
# A:   528
# T/F: T
# ----------
# Q:   15+46
# A:   60
# T/F: F
# ----------
# Q:   0+240
# A:   221
# T/F: F
# ----------
# Q:   233+22
# A:   255
# T/F: T
# ----------
# Q:   2+52
# A:   53
# T/F: F
# ----------
# Q:   475+224
# A:   799
# T/F: F
# ----------
# Q:   710+32
# A:   742
# T/F: T
# ----------
# Q:   952+451
# A:   1404
# T/F: F
# ----------
# Q:   894+1
# A:   895
# T/F: T
# ----------
# Q:   478+8
# A:   475
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 323us/step - loss: 0.6280 - acc: 0.7746 - val_loss: 0.6681 - val_acc: 0.7435
# ----------
# Q:   3+547
# A:   558
# T/F: F
# ----------
# Q:   536+106
# A:   563
# T/F: F
# ----------
# Q:   162+341
# A:   514
# T/F: F
# ----------
# Q:   89+328
# A:   427
# T/F: F
# ----------
# Q:   603+688
# A:   1228
# T/F: F
# ----------
# Q:   380+238
# A:   718
# T/F: F
# ----------
# Q:   243+783
# A:   1087
# T/F: F
# ----------
# Q:   811+77
# A:   888
# T/F: T
# ----------
# Q:   57+91
# A:   148
# T/F: T
# ----------
# Q:   894+1
# A:   896
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.5911 - acc: 0.7917 - val_loss: 0.6349 - val_acc: 0.7573
# ----------
# Q:   20+509
# A:   510
# T/F: F
# ----------
# Q:   95+997
# A:   1083
# T/F: F
# ----------
# Q:   83+904
# A:   997
# T/F: F
# ----------
# Q:   715+2
# A:   717
# T/F: T
# ----------
# Q:   823+921
# A:   1764
# T/F: F
# ----------
# Q:   768+4
# A:   783
# T/F: F
# ----------
# Q:   892+55
# A:   943
# T/F: F
# ----------
# Q:   352+1
# A:   353
# T/F: T
# ----------
# Q:   57+584
# A:   623
# T/F: F
# ----------
# Q:   715+2
# A:   717
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 323us/step - loss: 0.5596 - acc: 0.8055 - val_loss: 0.5935 - val_acc: 0.7837
# ----------
# Q:   253+97
# A:   330
# T/F: F
# ----------
# Q:   392+81
# A:   473
# T/F: T
# ----------
# Q:   648+806
# A:   1474
# T/F: F
# ----------
# Q:   93+363
# A:   436
# T/F: F
# ----------
# Q:   438+98
# A:   547
# T/F: F
# ----------
# Q:   949+88
# A:   1037
# T/F: T
# ----------
# Q:   719+265
# A:   954
# T/F: F
# ----------
# Q:   82+809
# A:   880
# T/F: F
# ----------
# Q:   261+66
# A:   387
# T/F: F
# ----------
# Q:   63+638
# A:   611
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 326us/step - loss: 0.5227 - acc: 0.8227 - val_loss: 0.5631 - val_acc: 0.7951
# ----------
# Q:   51+53
# A:   105
# T/F: F
# ----------
# Q:   16+37
# A:   53
# T/F: T
# ----------
# Q:   15+654
# A:   679
# T/F: F
# ----------
# Q:   62+11
# A:   73
# T/F: T
# ----------
# Q:   807+359
# A:   1116
# T/F: F
# ----------
# Q:   440+6
# A:   446
# T/F: T
# ----------
# Q:   435+75
# A:   419
# T/F: F
# ----------
# Q:   81+7
# A:   88
# T/F: T
# ----------
# Q:   950+10
# A:   961
# T/F: F
# ----------
# Q:   138+3
# A:   131
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 323us/step - loss: 0.4906 - acc: 0.8386 - val_loss: 0.5367 - val_acc: 0.8114
# ----------
# Q:   30+350
# A:   370
# T/F: F
# ----------
# Q:   76+42
# A:   119
# T/F: F
# ----------
# Q:   86+146
# A:   242
# T/F: F
# ----------
# Q:   38+829
# A:   867
# T/F: T
# ----------
# Q:   227+1
# A:   229
# T/F: F
# ----------
# Q:   93+741
# A:   834
# T/F: T
# ----------
# Q:   230+2
# A:   232
# T/F: T
# ----------
# Q:   453+789
# A:   1332
# T/F: F
# ----------
# Q:   563+90
# A:   643
# T/F: F
# ----------
# Q:   67+589
# A:   666
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 322us/step - loss: 0.4609 - acc: 0.8520 - val_loss: 0.5067 - val_acc: 0.8156
# ----------
# Q:   874+97
# A:   971
# T/F: T
# ----------
# Q:   559+20
# A:   579
# T/F: T
# ----------
# Q:   87+615
# A:   702
# T/F: T
# ----------
# Q:   522+7
# A:   529
# T/F: T
# ----------
# Q:   518+388
# A:   867
# T/F: F
# ----------
# Q:   2+485
# A:   487
# T/F: T
# ----------
# Q:   4+21
# A:   25
# T/F: T
# ----------
# Q:   103+7
# A:   101
# T/F: F
# ----------
# Q:   56+457
# A:   514
# T/F: F
# ----------
# Q:   9+852
# A:   851
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 331us/step - loss: 0.4380 - acc: 0.8602 - val_loss: 0.4837 - val_acc: 0.8284
# ----------
# Q:   901+82
# A:   993
# T/F: F
# ----------
# Q:   40+758
# A:   788
# T/F: F
# ----------
# Q:   266+8
# A:   284
# T/F: F
# ----------
# Q:   930+87
# A:   1007
# T/F: F
# ----------
# Q:   504+972
# A:   1486
# T/F: F
# ----------
# Q:   817+3
# A:   820
# T/F: T
# ----------
# Q:   2+265
# A:   267
# T/F: T
# ----------
# Q:   64+722
# A:   796
# T/F: F
# ----------
# Q:   661+96
# A:   757
# T/F: T
# ----------
# Q:   0+151
# A:   151
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 0.4125 - acc: 0.8729 - val_loss: 0.4676 - val_acc: 0.8346
# ----------
# Q:   958+38
# A:   987
# T/F: F
# ----------
# Q:   95+675
# A:   760
# T/F: F
# ----------
# Q:   28+92
# A:   110
# T/F: F
# ----------
# Q:   40+221
# A:   261
# T/F: T
# ----------
# Q:   84+92
# A:   176
# T/F: T
# ----------
# Q:   393+4
# A:   397
# T/F: T
# ----------
# Q:   3+918
# A:   921
# T/F: T
# ----------
# Q:   67+61
# A:   128
# T/F: T
# ----------
# Q:   0+853
# A:   853
# T/F: T
# ----------
# Q:   364+5
# A:   369
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 323us/step - loss: 0.3884 - acc: 0.8828 - val_loss: 0.4300 - val_acc: 0.8526
# ----------
# Q:   664+60
# A:   725
# T/F: F
# ----------
# Q:   542+48
# A:   590
# T/F: T
# ----------
# Q:   21+9
# A:   20
# T/F: F
# ----------
# Q:   751+6
# A:   757
# T/F: T
# ----------
# Q:   0+772
# A:   772
# T/F: T
# ----------
# Q:   27+809
# A:   836
# T/F: T
# ----------
# Q:   4+30
# A:   34
# T/F: T
# ----------
# Q:   939+281
# A:   1220
# T/F: T
# ----------
# Q:   0+279
# A:   289
# T/F: F
# ----------
# Q:   954+881
# A:   1835
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.3616 - acc: 0.8948 - val_loss: 0.4215 - val_acc: 0.8558
# ----------
# Q:   599+186
# A:   874
# T/F: F
# ----------
# Q:   198+57
# A:   245
# T/F: F
# ----------
# Q:   966+718
# A:   1694
# T/F: F
# ----------
# Q:   5+366
# A:   371
# T/F: T
# ----------
# Q:   180+90
# A:   290
# T/F: F
# ----------
# Q:   87+13
# A:   90
# T/F: F
# ----------
# Q:   5+713
# A:   718
# T/F: T
# ----------
# Q:   75+148
# A:   224
# T/F: F
# ----------
# Q:   93+239
# A:   332
# T/F: T
# ----------
# Q:   725+95
# A:   810
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.3422 - acc: 0.9012 - val_loss: 0.4039 - val_acc: 0.8619
# ----------
# Q:   4+539
# A:   543
# T/F: T
# ----------
# Q:   9+608
# A:   617
# T/F: T
# ----------
# Q:   69+15
# A:   84
# T/F: T
# ----------
# Q:   231+0
# A:   231
# T/F: T
# ----------
# Q:   45+51
# A:   96
# T/F: T
# ----------
# Q:   742+580
# A:   1382
# T/F: F
# ----------
# Q:   518+388
# A:   857
# T/F: F
# ----------
# Q:   327+603
# A:   959
# T/F: F
# ----------
# Q:   17+24
# A:   41
# T/F: T
# ----------
# Q:   404+8
# A:   412
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 320us/step - loss: 0.3244 - acc: 0.9074 - val_loss: 0.3851 - val_acc: 0.8721
# ----------
# Q:   445+69
# A:   514
# T/F: T
# ----------
# Q:   31+876
# A:   907
# T/F: T
# ----------
# Q:   88+667
# A:   765
# T/F: F
# ----------
# Q:   506+1
# A:   507
# T/F: T
# ----------
# Q:   69+15
# A:   84
# T/F: T
# ----------
# Q:   55+26
# A:   81
# T/F: T
# ----------
# Q:   952+838
# A:   1771
# T/F: F
# ----------
# Q:   745+496
# A:   1241
# T/F: T
# ----------
# Q:   805+99
# A:   904
# T/F: T
# ----------
# Q:   462+498
# A:   900
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 326us/step - loss: 0.3062 - acc: 0.9143 - val_loss: 0.3727 - val_acc: 0.8781
# ----------
# Q:   3+918
# A:   921
# T/F: T
# ----------
# Q:   93+43
# A:   136
# T/F: T
# ----------
# Q:   353+3
# A:   356
# T/F: T
# ----------
# Q:   0+864
# A:   864
# T/F: T
# ----------
# Q:   56+96
# A:   152
# T/F: T
# ----------
# Q:   56+0
# A:   56
# T/F: T
# ----------
# Q:   952+838
# A:   1790
# T/F: T
# ----------
# Q:   99+725
# A:   824
# T/F: T
# ----------
# Q:   184+5
# A:   199
# T/F: F
# ----------
# Q:   473+93
# A:   566
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.2872 - acc: 0.9211 - val_loss: 0.3529 - val_acc: 0.8844
# ----------
# Q:   217+682
# A:   998
# T/F: F
# ----------
# Q:   46+726
# A:   762
# T/F: F
# ----------
# Q:   139+67
# A:   296
# T/F: F
# ----------
# Q:   29+502
# A:   531
# T/F: T
# ----------
# Q:   91+78
# A:   169
# T/F: T
# ----------
# Q:   343+485
# A:   838
# T/F: F
# ----------
# Q:   29+581
# A:   600
# T/F: F
# ----------
# Q:   714+0
# A:   714
# T/F: T
# ----------
# Q:   914+180
# A:   1134
# T/F: F
# ----------
# Q:   100+73
# A:   173
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 329us/step - loss: 0.2695 - acc: 0.9274 - val_loss: 0.3415 - val_acc: 0.8877
# ----------
# Q:   4+520
# A:   524
# T/F: T
# ----------
# Q:   67+83
# A:   150
# T/F: T
# ----------
# Q:   689+1
# A:   690
# T/F: T
# ----------
# Q:   60+27
# A:   77
# T/F: F
# ----------
# Q:   98+368
# A:   466
# T/F: T
# ----------
# Q:   704+4
# A:   708
# T/F: T
# ----------
# Q:   73+561
# A:   634
# T/F: T
# ----------
# Q:   4+844
# A:   848
# T/F: T
# ----------
# Q:   39+16
# A:   55
# T/F: T
# ----------
# Q:   93+559
# A:   642
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.2567 - acc: 0.9313 - val_loss: 0.3282 - val_acc: 0.8896
# ----------
# Q:   598+2
# A:   601
# T/F: F
# ----------
# Q:   85+810
# A:   895
# T/F: T
# ----------
# Q:   294+1
# A:   295
# T/F: T
# ----------
# Q:   438+87
# A:   525
# T/F: T
# ----------
# Q:   19+696
# A:   715
# T/F: T
# ----------
# Q:   76+450
# A:   526
# T/F: T
# ----------
# Q:   923+62
# A:   975
# T/F: F
# ----------
# Q:   78+12
# A:   90
# T/F: T
# ----------
# Q:   482+91
# A:   573
# T/F: T
# ----------
# Q:   626+4
# A:   630
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.2442 - acc: 0.9339 - val_loss: 0.3146 - val_acc: 0.8947
# ----------
# Q:   691+1
# A:   692
# T/F: T
# ----------
# Q:   578+70
# A:   658
# T/F: F
# ----------
# Q:   747+14
# A:   761
# T/F: T
# ----------
# Q:   119+39
# A:   148
# T/F: F
# ----------
# Q:   648+21
# A:   669
# T/F: T
# ----------
# Q:   742+3
# A:   745
# T/F: T
# ----------
# Q:   267+6
# A:   273
# T/F: T
# ----------
# Q:   752+4
# A:   756
# T/F: T
# ----------
# Q:   591+97
# A:   678
# T/F: F
# ----------
# Q:   327+79
# A:   416
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.2267 - acc: 0.9415 - val_loss: 0.3022 - val_acc: 0.8971
# ----------
# Q:   8+867
# A:   875
# T/F: T
# ----------
# Q:   47+179
# A:   216
# T/F: F
# ----------
# Q:   542+48
# A:   590
# T/F: T
# ----------
# Q:   338+86
# A:   424
# T/F: T
# ----------
# Q:   288+8
# A:   396
# T/F: F
# ----------
# Q:   347+5
# A:   352
# T/F: T
# ----------
# Q:   725+95
# A:   819
# T/F: F
# ----------
# Q:   988+618
# A:   1676
# T/F: F
# ----------
# Q:   976+46
# A:   1022
# T/F: T
# ----------
# Q:   46+55
# A:   100
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.2220 - acc: 0.9407 - val_loss: 0.3086 - val_acc: 0.8947
# ----------
# Q:   29+87
# A:   116
# T/F: T
# ----------
# Q:   8+407
# A:   415
# T/F: T
# ----------
# Q:   688+6
# A:   694
# T/F: T
# ----------
# Q:   38+829
# A:   867
# T/F: T
# ----------
# Q:   516+751
# A:   1287
# T/F: F
# ----------
# Q:   3+847
# A:   851
# T/F: F
# ----------
# Q:   32+452
# A:   474
# T/F: F
# ----------
# Q:   593+586
# A:   1249
# T/F: F
# ----------
# Q:   786+310
# A:   1076
# T/F: F
# ----------
# Q:   174+42
# A:   206
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 0.2046 - acc: 0.9474 - val_loss: 0.2826 - val_acc: 0.9050
# ----------
# Q:   8+852
# A:   860
# T/F: T
# ----------
# Q:   754+6
# A:   760
# T/F: T
# ----------
# Q:   36+81
# A:   117
# T/F: T
# ----------
# Q:   839+97
# A:   936
# T/F: T
# ----------
# Q:   619+137
# A:   766
# T/F: F
# ----------
# Q:   909+678
# A:   1577
# T/F: F
# ----------
# Q:   88+625
# A:   723
# T/F: F
# ----------
# Q:   923+62
# A:   975
# T/F: F
# ----------
# Q:   1+62
# A:   63
# T/F: T
# ----------
# Q:   933+44
# A:   977
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 0.1937 - acc: 0.9518 - val_loss: 0.2916 - val_acc: 0.9007
# ----------
# Q:   454+43
# A:   497
# T/F: T
# ----------
# Q:   787+8
# A:   795
# T/F: T
# ----------
# Q:   57+91
# A:   148
# T/F: T
# ----------
# Q:   830+6
# A:   836
# T/F: T
# ----------
# Q:   533+5
# A:   538
# T/F: T
# ----------
# Q:   911+4
# A:   915
# T/F: T
# ----------
# Q:   525+935
# A:   1460
# T/F: T
# ----------
# Q:   31+8
# A:   39
# T/F: T
# ----------
# Q:   86+558
# A:   644
# T/F: T
# ----------
# Q:   477+7
# A:   484
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 332us/step - loss: 0.1834 - acc: 0.9545 - val_loss: 0.2628 - val_acc: 0.9123
# ----------
# Q:   23+869
# A:   892
# T/F: T
# ----------
# Q:   261+66
# A:   337
# T/F: F
# ----------
# Q:   358+23
# A:   381
# T/F: T
# ----------
# Q:   804+2
# A:   806
# T/F: T
# ----------
# Q:   15+2
# A:   27
# T/F: F
# ----------
# Q:   137+68
# A:   295
# T/F: F
# ----------
# Q:   310+480
# A:   790
# T/F: T
# ----------
# Q:   970+319
# A:   1399
# T/F: F
# ----------
# Q:   57+91
# A:   148
# T/F: T
# ----------
# Q:   90+9
# A:   99
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 330us/step - loss: 0.1730 - acc: 0.9588 - val_loss: 0.2529 - val_acc: 0.9161
# ----------
# Q:   44+216
# A:   260
# T/F: T
# ----------
# Q:   221+5
# A:   226
# T/F: T
# ----------
# Q:   494+32
# A:   526
# T/F: T
# ----------
# Q:   382+24
# A:   406
# T/F: T
# ----------
# Q:   542+3
# A:   545
# T/F: T
# ----------
# Q:   1+901
# A:   902
# T/F: T
# ----------
# Q:   231+80
# A:   311
# T/F: T
# ----------
# Q:   973+96
# A:   1079
# T/F: F
# ----------
# Q:   70+3
# A:   73
# T/F: T
# ----------
# Q:   928+92
# A:   1020
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 0.1631 - acc: 0.9617 - val_loss: 0.2495 - val_acc: 0.9179
# ----------
# Q:   305+33
# A:   338
# T/F: T
# ----------
# Q:   5+113
# A:   118
# T/F: T
# ----------
# Q:   5+13
# A:   18
# T/F: T
# ----------
# Q:   139+9
# A:   148
# T/F: T
# ----------
# Q:   451+261
# A:   712
# T/F: T
# ----------
# Q:   988+9
# A:   997
# T/F: T
# ----------
# Q:   27+98
# A:   125
# T/F: T
# ----------
# Q:   417+526
# A:   963
# T/F: F
# ----------
# Q:   453+789
# A:   1233
# T/F: F
# ----------
# Q:   899+426
# A:   1325
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 0.1594 - acc: 0.9613 - val_loss: 0.2564 - val_acc: 0.9130
# ----------
# Q:   553+552
# A:   1105
# T/F: T
# ----------
# Q:   205+65
# A:   270
# T/F: T
# ----------
# Q:   45+314
# A:   359
# T/F: T
# ----------
# Q:   181+73
# A:   254
# T/F: T
# ----------
# Q:   8+688
# A:   696
# T/F: T
# ----------
# Q:   51+741
# A:   792
# T/F: T
# ----------
# Q:   628+9
# A:   637
# T/F: T
# ----------
# Q:   611+10
# A:   621
# T/F: T
# ----------
# Q:   881+466
# A:   1357
# T/F: F
# ----------
# Q:   453+4
# A:   457
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 326us/step - loss: 0.1495 - acc: 0.9651 - val_loss: 0.2368 - val_acc: 0.9192
# ----------
# Q:   795+709
# A:   1594
# T/F: F
# ----------
# Q:   127+86
# A:   213
# T/F: T
# ----------
# Q:   617+55
# A:   672
# T/F: T
# ----------
# Q:   863+561
# A:   1413
# T/F: F
# ----------
# Q:   735+289
# A:   1034
# T/F: F
# ----------
# Q:   171+82
# A:   253
# T/F: T
# ----------
# Q:   739+0
# A:   739
# T/F: T
# ----------
# Q:   6+463
# A:   479
# T/F: F
# ----------
# Q:   90+398
# A:   488
# T/F: T
# ----------
# Q:   39+0
# A:   39
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 324us/step - loss: 0.1475 - acc: 0.9636 - val_loss: 0.2434 - val_acc: 0.9151
# ----------
# Q:   40+92
# A:   132
# T/F: T
# ----------
# Q:   64+50
# A:   114
# T/F: T
# ----------
# Q:   6+323
# A:   329
# T/F: T
# ----------
# Q:   714+0
# A:   714
# T/F: T
# ----------
# Q:   881+224
# A:   1105
# T/F: T
# ----------
# Q:   34+60
# A:   94
# T/F: T
# ----------
# Q:   742+3
# A:   745
# T/F: T
# ----------
# Q:   108+80
# A:   188
# T/F: T
# ----------
# Q:   686+3
# A:   689
# T/F: T
# ----------
# Q:   30+3
# A:   33
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 0.1379 - acc: 0.9681 - val_loss: 0.2279 - val_acc: 0.9237
# ----------
# Q:   58+120
# A:   168
# T/F: F
# ----------
# Q:   760+92
# A:   852
# T/F: T
# ----------
# Q:   168+280
# A:   438
# T/F: F
# ----------
# Q:   287+30
# A:   317
# T/F: T
# ----------
# Q:   642+4
# A:   646
# T/F: T
# ----------
# Q:   21+105
# A:   126
# T/F: T
# ----------
# Q:   77+808
# A:   895
# T/F: F
# ----------
# Q:   56+22
# A:   78
# T/F: T
# ----------
# Q:   5+164
# A:   169
# T/F: T
# ----------
# Q:   675+1
# A:   676
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 324us/step - loss: 0.1389 - acc: 0.9661 - val_loss: 0.2256 - val_acc: 0.9201
# ----------
# Q:   72+942
# A:   1004
# T/F: F
# ----------
# Q:   4+720
# A:   724
# T/F: T
# ----------
# Q:   87+41
# A:   128
# T/F: T
# ----------
# Q:   37+62
# A:   90
# T/F: F
# ----------
# Q:   540+143
# A:   573
# T/F: F
# ----------
# Q:   39+40
# A:   89
# T/F: F
# ----------
# Q:   39+16
# A:   55
# T/F: T
# ----------
# Q:   854+797
# A:   1652
# T/F: F
# ----------
# Q:   4+844
# A:   848
# T/F: T
# ----------
# Q:   36+496
# A:   522
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 0.1332 - acc: 0.9678 - val_loss: 0.2270 - val_acc: 0.9194
# ----------
# Q:   1+203
# A:   204
# T/F: T
# ----------
# Q:   71+481
# A:   552
# T/F: T
# ----------
# Q:   448+270
# A:   718
# T/F: T
# ----------
# Q:   484+48
# A:   542
# T/F: F
# ----------
# Q:   8+420
# A:   428
# T/F: T
# ----------
# Q:   74+249
# A:   323
# T/F: T
# ----------
# Q:   27+82
# A:   119
# T/F: F
# ----------
# Q:   790+82
# A:   862
# T/F: F
# ----------
# Q:   400+12
# A:   422
# T/F: F
# ----------
# Q:   961+26
# A:   987
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 0.1349 - acc: 0.9657 - val_loss: 0.2091 - val_acc: 0.9286
# ----------
# Q:   546+0
# A:   546
# T/F: T
# ----------
# Q:   936+51
# A:   997
# T/F: F
# ----------
# Q:   4+333
# A:   337
# T/F: T
# ----------
# Q:   148+240
# A:   488
# T/F: F
# ----------
# Q:   722+40
# A:   762
# T/F: T
# ----------
# Q:   9+808
# A:   817
# T/F: T
# ----------
# Q:   424+3
# A:   427
# T/F: T
# ----------
# Q:   38+33
# A:   71
# T/F: T
# ----------
# Q:   148+240
# A:   488
# T/F: F
# ----------
# Q:   21+27
# A:   48
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 337us/step - loss: 0.1099 - acc: 0.9778 - val_loss: 0.1977 - val_acc: 0.9320
# ----------
# Q:   584+529
# A:   1123
# T/F: F
# ----------
# Q:   897+460
# A:   1357
# T/F: T
# ----------
# Q:   27+82
# A:   109
# T/F: T
# ----------
# Q:   14+55
# A:   69
# T/F: T
# ----------
# Q:   872+154
# A:   1047
# T/F: F
# ----------
# Q:   126+935
# A:   1061
# T/F: T
# ----------
# Q:   487+519
# A:   1076
# T/F: F
# ----------
# Q:   266+4
# A:   270
# T/F: T
# ----------
# Q:   99+971
# A:   1070
# T/F: T
# ----------
# Q:   880+40
# A:   920
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.1041 - acc: 0.9792 - val_loss: 0.2026 - val_acc: 0.9318
# ----------
# Q:   395+604
# A:   1009
# T/F: F
# ----------
# Q:   3+898
# A:   901
# T/F: T
# ----------
# Q:   30+57
# A:   87
# T/F: T
# ----------
# Q:   39+33
# A:   72
# T/F: T
# ----------
# Q:   2+343
# A:   345
# T/F: T
# ----------
# Q:   520+764
# A:   1284
# T/F: T
# ----------
# Q:   484+48
# A:   532
# T/F: T
# ----------
# Q:   254+310
# A:   574
# T/F: F
# ----------
# Q:   51+31
# A:   82
# T/F: T
# ----------
# Q:   110+4
# A:   114
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 326us/step - loss: 0.0993 - acc: 0.9815 - val_loss: 0.1920 - val_acc: 0.9350
# ----------
# Q:   50+301
# A:   351
# T/F: T
# ----------
# Q:   75+328
# A:   403
# T/F: T
# ----------
# Q:   0+751
# A:   751
# T/F: T
# ----------
# Q:   19+12
# A:   31
# T/F: T
# ----------
# Q:   892+4
# A:   896
# T/F: T
# ----------
# Q:   907+3
# A:   910
# T/F: T
# ----------
# Q:   1+138
# A:   139
# T/F: T
# ----------
# Q:   729+38
# A:   767
# T/F: T
# ----------
# Q:   119+18
# A:   137
# T/F: T
# ----------
# Q:   575+1
# A:   576
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.0943 - acc: 0.9820 - val_loss: 0.1925 - val_acc: 0.9342
# ----------
# Q:   10+1
# A:   11
# T/F: T
# ----------
# Q:   0+397
# A:   397
# T/F: T
# ----------
# Q:   18+45
# A:   63
# T/F: T
# ----------
# Q:   33+864
# A:   897
# T/F: T
# ----------
# Q:   81+865
# A:   946
# T/F: T
# ----------
# Q:   817+3
# A:   820
# T/F: T
# ----------
# Q:   546+4
# A:   550
# T/F: T
# ----------
# Q:   387+3
# A:   380
# T/F: F
# ----------
# Q:   4+311
# A:   315
# T/F: T
# ----------
# Q:   877+982
# A:   1869
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 0.0954 - acc: 0.9804 - val_loss: 0.1925 - val_acc: 0.9343
# ----------
# Q:   139+308
# A:   447
# T/F: T
# ----------
# Q:   82+239
# A:   321
# T/F: T
# ----------
# Q:   729+74
# A:   803
# T/F: T
# ----------
# Q:   231+0
# A:   231
# T/F: T
# ----------
# Q:   10+790
# A:   800
# T/F: T
# ----------
# Q:   69+483
# A:   552
# T/F: T
# ----------
# Q:   822+76
# A:   898
# T/F: T
# ----------
# Q:   90+89
# A:   189
# T/F: F
# ----------
# Q:   19+12
# A:   31
# T/F: T
# ----------
# Q:   40+3
# A:   43
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.0881 - acc: 0.9839 - val_loss: 0.1832 - val_acc: 0.9381
# ----------
# Q:   361+675
# A:   1037
# T/F: F
# ----------
# Q:   35+118
# A:   153
# T/F: T
# ----------
# Q:   912+221
# A:   1133
# T/F: T
# ----------
# Q:   30+767
# A:   897
# T/F: F
# ----------
# Q:   256+35
# A:   291
# T/F: T
# ----------
# Q:   67+98
# A:   165
# T/F: T
# ----------
# Q:   15+46
# A:   61
# T/F: T
# ----------
# Q:   904+18
# A:   922
# T/F: T
# ----------
# Q:   74+63
# A:   137
# T/F: T
# ----------
# Q:   39+11
# A:   40
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 330us/step - loss: 0.0826 - acc: 0.9857 - val_loss: 0.1835 - val_acc: 0.9344
# ----------
# Q:   37+693
# A:   720
# T/F: F
# ----------
# Q:   120+821
# A:   911
# T/F: F
# ----------
# Q:   139+30
# A:   169
# T/F: T
# ----------
# Q:   374+227
# A:   690
# T/F: F
# ----------
# Q:   55+635
# A:   690
# T/F: T
# ----------
# Q:   921+66
# A:   977
# T/F: F
# ----------
# Q:   571+673
# A:   1244
# T/F: T
# ----------
# Q:   162+341
# A:   403
# T/F: F
# ----------
# Q:   536+130
# A:   666
# T/F: T
# ----------
# Q:   8+867
# A:   875
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 0.0781 - acc: 0.9868 - val_loss: 0.1782 - val_acc: 0.9380
# ----------
# Q:   38+427
# A:   465
# T/F: T
# ----------
# Q:   1+690
# A:   691
# T/F: T
# ----------
# Q:   454+43
# A:   497
# T/F: T
# ----------
# Q:   54+70
# A:   124
# T/F: T
# ----------
# Q:   105+109
# A:   114
# T/F: F
# ----------
# Q:   516+5
# A:   521
# T/F: T
# ----------
# Q:   81+865
# A:   946
# T/F: T
# ----------
# Q:   2+509
# A:   511
# T/F: T
# ----------
# Q:   6+942
# A:   948
# T/F: T
# ----------
# Q:   1+927
# A:   928
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.0743 - acc: 0.9883 - val_loss: 0.1718 - val_acc: 0.9387
# ----------
# Q:   358+23
# A:   381
# T/F: T
# ----------
# Q:   807+359
# A:   1156
# T/F: F
# ----------
# Q:   84+158
# A:   242
# T/F: T
# ----------
# Q:   387+3
# A:   380
# T/F: F
# ----------
# Q:   938+222
# A:   1140
# T/F: F
# ----------
# Q:   867+3
# A:   870
# T/F: T
# ----------
# Q:   430+709
# A:   1139
# T/F: T
# ----------
# Q:   47+179
# A:   216
# T/F: F
# ----------
# Q:   955+765
# A:   1610
# T/F: F
# ----------
# Q:   574+34
# A:   508
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 0.0748 - acc: 0.9870 - val_loss: 0.1773 - val_acc: 0.9404
# ----------
# Q:   542+3
# A:   545
# T/F: T
# ----------
# Q:   492+268
# A:   760
# T/F: T
# ----------
# Q:   413+54
# A:   467
# T/F: T
# ----------
# Q:   689+8
# A:   697
# T/F: T
# ----------
# Q:   37+208
# A:   245
# T/F: T
# ----------
# Q:   0+439
# A:   439
# T/F: T
# ----------
# Q:   397+390
# A:   787
# T/F: T
# ----------
# Q:   17+25
# A:   42
# T/F: T
# ----------
# Q:   945+1
# A:   946
# T/F: T
# ----------
# Q:   64+970
# A:   1034
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 0.0719 - acc: 0.9883 - val_loss: 0.1834 - val_acc: 0.9348
# ----------
# Q:   142+848
# A:   990
# T/F: T
# ----------
# Q:   3+148
# A:   151
# T/F: T
# ----------
# Q:   0+439
# A:   439
# T/F: T
# ----------
# Q:   930+87
# A:   1017
# T/F: T
# ----------
# Q:   154+9
# A:   163
# T/F: T
# ----------
# Q:   794+907
# A:   1701
# T/F: T
# ----------
# Q:   19+923
# A:   942
# T/F: T
# ----------
# Q:   302+514
# A:   826
# T/F: F
# ----------
# Q:   215+9
# A:   224
# T/F: T
# ----------
# Q:   952+451
# A:   1403
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 323us/step - loss: 0.0695 - acc: 0.9887 - val_loss: 0.1734 - val_acc: 0.9396
# ----------
# Q:   398+18
# A:   416
# T/F: T
# ----------
# Q:   63+63
# A:   126
# T/F: T
# ----------
# Q:   670+132
# A:   803
# T/F: F
# ----------
# Q:   898+0
# A:   898
# T/F: T
# ----------
# Q:   7+756
# A:   763
# T/F: T
# ----------
# Q:   4+245
# A:   259
# T/F: F
# ----------
# Q:   139+6
# A:   145
# T/F: T
# ----------
# Q:   2+128
# A:   130
# T/F: T
# ----------
# Q:   6+869
# A:   875
# T/F: T
# ----------
# Q:   445+69
# A:   524
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 324us/step - loss: 0.0725 - acc: 0.9867 - val_loss: 0.2484 - val_acc: 0.9070
# ----------
# Q:   523+835
# A:   1368
# T/F: F
# ----------
# Q:   622+8
# A:   630
# T/F: T
# ----------
# Q:   9+340
# A:   349
# T/F: T
# ----------
# Q:   38+33
# A:   71
# T/F: T
# ----------
# Q:   36+74
# A:   110
# T/F: T
# ----------
# Q:   31+19
# A:   50
# T/F: T
# ----------
# Q:   493+680
# A:   1253
# T/F: F
# ----------
# Q:   787+82
# A:   869
# T/F: T
# ----------
# Q:   5+994
# A:   999
# T/F: T
# ----------
# Q:   139+67
# A:   206
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 323us/step - loss: 0.1031 - acc: 0.9716 - val_loss: 0.1808 - val_acc: 0.9364
# ----------
# Q:   3+898
# A:   901
# T/F: T
# ----------
# Q:   6+929
# A:   935
# T/F: T
# ----------
# Q:   69+6
# A:   75
# T/F: T
# ----------
# Q:   231+0
# A:   231
# T/F: T
# ----------
# Q:   4+333
# A:   337
# T/F: T
# ----------
# Q:   72+257
# A:   339
# T/F: F
# ----------
# Q:   94+746
# A:   830
# T/F: F
# ----------
# Q:   641+197
# A:   838
# T/F: T
# ----------
# Q:   79+20
# A:   990
# T/F: F
# ----------
# Q:   901+8
# A:   909
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 339us/step - loss: 0.0633 - acc: 0.9896 - val_loss: 0.1624 - val_acc: 0.9449
# ----------
# Q:   9+927
# A:   936
# T/F: T
# ----------
# Q:   23+359
# A:   382
# T/F: T
# ----------
# Q:   952+838
# A:   1780
# T/F: F
# ----------
# Q:   56+52
# A:   108
# T/F: T
# ----------
# Q:   656+269
# A:   915
# T/F: F
# ----------
# Q:   577+0
# A:   577
# T/F: T
# ----------
# Q:   72+257
# A:   329
# T/F: T
# ----------
# Q:   70+22
# A:   92
# T/F: T
# ----------
# Q:   19+171
# A:   290
# T/F: F
# ----------
# Q:   780+279
# A:   1089
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 7s 392us/step - loss: 0.0515 - acc: 0.9945 - val_loss: 0.1568 - val_acc: 0.9450
# ----------
# Q:   912+221
# A:   1133
# T/F: T
# ----------
# Q:   656+269
# A:   915
# T/F: F
# ----------
# Q:   54+16
# A:   70
# T/F: T
# ----------
# Q:   15+4
# A:   19
# T/F: T
# ----------
# Q:   65+888
# A:   953
# T/F: T
# ----------
# Q:   3+998
# A:   1001
# T/F: T
# ----------
# Q:   76+534
# A:   610
# T/F: T
# ----------
# Q:   644+873
# A:   1517
# T/F: T
# ----------
# Q:   816+9
# A:   825
# T/F: T
# ----------
# Q:   492+221
# A:   723
# T/F: F
# ----------
# ...
# A:   369
# T/F: T
# ----------
# Q:   758+4
# A:   762
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 320us/step - loss: 0.0078 - acc: 0.9999 - val_loss: 0.1307 - val_acc: 0.9596
# ----------
# Q:   31+19
# A:   40
# T/F: F
# ----------
# Q:   44+200
# A:   244
# T/F: T
# ----------
# Q:   383+7
# A:   390
# T/F: T
# ----------
# Q:   6+282
# A:   288
# T/F: T
# ----------
# Q:   5+669
# A:   674
# T/F: T
# ----------
# Q:   2+52
# A:   54
# T/F: T
# ----------
# Q:   42+37
# A:   79
# T/F: T
# ----------
# Q:   1+187
# A:   188
# T/F: T
# ----------
# Q:   42+282
# A:   324
# T/F: T
# ----------
# Q:   11+696
# A:   707
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 333us/step - loss: 0.0058 - acc: 1.0000 - val_loss: 0.1298 - val_acc: 0.9600
# ----------
# Q:   711+5
# A:   716
# T/F: T
# ----------
# Q:   343+52
# A:   395
# T/F: T
# ----------
# Q:   971+467
# A:   1328
# T/F: F
# ----------
# Q:   846+39
# A:   885
# T/F: T
# ----------
# Q:   706+56
# A:   762
# T/F: T
# ----------
# Q:   10+610
# A:   620
# T/F: T
# ----------
# Q:   19+68
# A:   87
# T/F: T
# ----------
# Q:   261+66
# A:   327
# T/F: T
# ----------
# Q:   33+75
# A:   108
# T/F: T
# ----------
# Q:   3+56
# A:   69
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 324us/step - loss: 0.0052 - acc: 1.0000 - val_loss: 0.1304 - val_acc: 0.9597
# ----------
# Q:   27+436
# A:   463
# T/F: T
# ----------
# Q:   6+328
# A:   334
# T/F: T
# ----------
# Q:   506+1
# A:   507
# T/F: T
# ----------
# Q:   64+722
# A:   786
# T/F: T
# ----------
# Q:   45+314
# A:   359
# T/F: T
# ----------
# Q:   872+408
# A:   1280
# T/F: T
# ----------
# Q:   305+44
# A:   358
# T/F: F
# ----------
# Q:   74+63
# A:   137
# T/F: T
# ----------
# Q:   139+6
# A:   145
# T/F: T
# ----------
# Q:   545+626
# A:   1171
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.0048 - acc: 1.0000 - val_loss: 0.1296 - val_acc: 0.9596
# ----------
# Q:   8+719
# A:   727
# T/F: T
# ----------
# Q:   38+427
# A:   465
# T/F: T
# ----------
# Q:   50+96
# A:   146
# T/F: T
# ----------
# Q:   775+9
# A:   784
# T/F: T
# ----------
# Q:   15+46
# A:   61
# T/F: T
# ----------
# Q:   795+50
# A:   835
# T/F: F
# ----------
# Q:   462+52
# A:   514
# T/F: T
# ----------
# Q:   871+651
# A:   1522
# T/F: T
# ----------
# Q:   73+561
# A:   634
# T/F: T
# ----------
# Q:   16+151
# A:   167
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 329us/step - loss: 0.0045 - acc: 1.0000 - val_loss: 0.1307 - val_acc: 0.9584
# ----------
# Q:   141+2
# A:   143
# T/F: T
# ----------
# Q:   183+761
# A:   954
# T/F: F
# ----------
# Q:   5+761
# A:   766
# T/F: T
# ----------
# Q:   903+843
# A:   1746
# T/F: T
# ----------
# Q:   91+72
# A:   163
# T/F: T
# ----------
# Q:   141+903
# A:   1044
# T/F: T
# ----------
# Q:   45+314
# A:   359
# T/F: T
# ----------
# Q:   4+414
# A:   418
# T/F: T
# ----------
# Q:   100+73
# A:   173
# T/F: T
# ----------
# Q:   3+936
# A:   939
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 0.0043 - acc: 1.0000 - val_loss: 0.1305 - val_acc: 0.9599
# ----------
# Q:   379+37
# A:   416
# T/F: T
# ----------
# Q:   48+21
# A:   69
# T/F: T
# ----------
# Q:   575+1
# A:   576
# T/F: T
# ----------
# Q:   142+848
# A:   990
# T/F: T
# ----------
# Q:   19+529
# A:   548
# T/F: T
# ----------
# Q:   89+289
# A:   388
# T/F: F
# ----------
# Q:   367+5
# A:   372
# T/F: T
# ----------
# Q:   205+18
# A:   223
# T/F: T
# ----------
# Q:   952+451
# A:   1403
# T/F: T
# ----------
# Q:   365+56
# A:   421
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 0.0041 - acc: 1.0000 - val_loss: 0.1303 - val_acc: 0.9594
# ----------
# Q:   8+412
# A:   420
# T/F: T
# ----------
# Q:   34+223
# A:   257
# T/F: T
# ----------
# Q:   35+159
# A:   194
# T/F: T
# ----------
# Q:   710+6
# A:   716
# T/F: T
# ----------
# Q:   94+289
# A:   383
# T/F: T
# ----------
# Q:   94+45
# A:   139
# T/F: T
# ----------
# Q:   37+388
# A:   425
# T/F: T
# ----------
# Q:   994+142
# A:   1126
# T/F: F
# ----------
# Q:   64+722
# A:   786
# T/F: T
# ----------
# Q:   54+464
# A:   518
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 326us/step - loss: 0.0039 - acc: 1.0000 - val_loss: 0.1310 - val_acc: 0.9596
# ----------
# Q:   923+62
# A:   975
# T/F: F
# ----------
# Q:   74+693
# A:   767
# T/F: T
# ----------
# Q:   282+87
# A:   379
# T/F: F
# ----------
# Q:   233+22
# A:   255
# T/F: T
# ----------
# Q:   279+945
# A:   1234
# T/F: F
# ----------
# Q:   448+557
# A:   1005
# T/F: T
# ----------
# Q:   39+46
# A:   85
# T/F: T
# ----------
# Q:   907+557
# A:   1463
# T/F: F
# ----------
# Q:   871+164
# A:   1045
# T/F: F
# ----------
# Q:   14+606
# A:   620
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 325us/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.1320 - val_acc: 0.9586
# ----------
# Q:   63+2
# A:   65
# T/F: T
# ----------
# Q:   861+822
# A:   1683
# T/F: T
# ----------
# Q:   120+222
# A:   342
# T/F: T
# ----------
# Q:   61+588
# A:   649
# T/F: T
# ----------
# Q:   8+852
# A:   860
# T/F: T
# ----------
# Q:   3+96
# A:   19
# T/F: F
# ----------
# Q:   231+0
# A:   231
# T/F: T
# ----------
# Q:   74+693
# A:   767
# T/F: T
# ----------
# Q:   500+884
# A:   1384
# T/F: T
# ----------
# Q:   18+45
# A:   63
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 324us/step - loss: 0.0036 - acc: 1.0000 - val_loss: 0.1330 - val_acc: 0.9596
# ----------
# Q:   40+3
# A:   43
# T/F: T
# ----------
# Q:   15+940
# A:   955
# T/F: T
# ----------
# Q:   406+8
# A:   414
# T/F: T
# ----------
# Q:   82+23
# A:   105
# T/F: T
# ----------
# Q:   800+4
# A:   804
# T/F: T
# ----------
# Q:   73+886
# A:   959
# T/F: T
# ----------
# Q:   406+8
# A:   414
# T/F: T
# ----------
# Q:   9+941
# A:   950
# T/F: T
# ----------
# Q:   3+120
# A:   123
# T/F: T
# ----------
# Q:   63+153
# A:   216
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 324us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.1326 - val_acc: 0.9591
# ----------
# Q:   69+483
# A:   552
# T/F: T
# ----------
# Q:   512+3
# A:   515
# T/F: T
# ----------
# Q:   678+7
# A:   685
# T/F: T
# ----------
# Q:   13+201
# A:   214
# T/F: T
# ----------
# Q:   518+796
# A:   1314
# T/F: T
# ----------
# Q:   117+0
# A:   117
# T/F: T
# ----------
# Q:   861+822
# A:   1683
# T/F: T
# ----------
# Q:   792+5
# A:   797
# T/F: T
# ----------
# Q:   155+6
# A:   161
# T/F: T
# ----------
# Q:   183+89
# A:   272
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 323us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.1330 - val_acc: 0.9588
# ----------
# Q:   391+82
# A:   473
# T/F: T
# ----------
# Q:   10+790
# A:   700
# T/F: F
# ----------
# Q:   33+642
# A:   675
# T/F: T
# ----------
# Q:   45+314
# A:   359
# T/F: T
# ----------
# Q:   38+834
# A:   872
# T/F: T
# ----------
# Q:   345+92
# A:   437
# T/F: T
# ----------
# Q:   928+92
# A:   1020
# T/F: T
# ----------
# Q:   1+642
# A:   643
# T/F: T
# ----------
# Q:   7+502
# A:   509
# T/F: T
# ----------
# Q:   8+25
# A:   33
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 321us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.1338 - val_acc: 0.9584
# ----------
# Q:   5+17
# A:   22
# T/F: T
# ----------
# Q:   542+26
# A:   568
# T/F: T
# ----------
# Q:   542+48
# A:   590
# T/F: T
# ----------
# Q:   358+925
# A:   1294
# T/F: F
# ----------
# Q:   335+99
# A:   434
# T/F: T
# ----------
# Q:   625+3
# A:   628
# T/F: T
# ----------
# Q:   752+2
# A:   754
# T/F: T
# ----------
# Q:   1+63
# A:   64
# T/F: T
# ----------
# Q:   148+44
# A:   192
# T/F: T
# ----------
# Q:   29+87
# A:   116
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 329us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.1337 - val_acc: 0.9585
# ----------
# Q:   578+70
# A:   648
# T/F: T
# ----------
# Q:   25+91
# A:   116
# T/F: T
# ----------
# Q:   453+4
# A:   457
# T/F: T
# ----------
# Q:   910+83
# A:   993
# T/F: T
# ----------
# Q:   1+63
# A:   64
# T/F: T
# ----------
# Q:   8+852
# A:   860
# T/F: T
# ----------
# Q:   878+5
# A:   883
# T/F: T
# ----------
# Q:   895+582
# A:   1477
# T/F: T
# ----------
# Q:   422+589
# A:   1011
# T/F: T
# ----------
# Q:   387+350
# A:   737
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 329us/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.1339 - val_acc: 0.9595
# ----------
# Q:   648+118
# A:   766
# T/F: T
# ----------
# Q:   382+70
# A:   452
# T/F: T
# ----------
# Q:   60+241
# A:   301
# T/F: T
# ----------
# Q:   71+399
# A:   460
# T/F: F
# ----------
# Q:   49+33
# A:   82
# T/F: T
# ----------
# Q:   448+60
# A:   508
# T/F: T
# ----------
# Q:   828+360
# A:   1188
# T/F: T
# ----------
# Q:   906+48
# A:   954
# T/F: T
# ----------
# Q:   47+739
# A:   786
# T/F: T
# ----------
# Q:   1+121
# A:   122
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 328us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.1346 - val_acc: 0.9590
# ----------
# Q:   38+829
# A:   867
# T/F: T
# ----------
# Q:   861+822
# A:   1683
# T/F: T
# ----------
# Q:   766+352
# A:   1118
# T/F: T
# ----------
# Q:   837+531
# A:   1368
# T/F: T
# ----------
# Q:   467+3
# A:   470
# T/F: T
# ----------
# Q:   4+226
# A:   230
# T/F: T
# ----------
# Q:   6+397
# A:   403
# T/F: T
# ----------
# Q:   81+20
# A:   101
# T/F: T
# ----------
# Q:   430+709
# A:   1149
# T/F: F
# ----------
# Q:   473+65
# A:   538
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 337us/step - loss: 0.0028 - acc: 1.0000 - val_loss: 0.1357 - val_acc: 0.9587
# ----------
# Q:   16+569
# A:   584
# T/F: F
# ----------
# Q:   8+826
# A:   834
# T/F: T
# ----------
# Q:   473+65
# A:   538
# T/F: T
# ----------
# Q:   38+829
# A:   867
# T/F: T
# ----------
# Q:   0+531
# A:   531
# T/F: T
# ----------
# Q:   987+78
# A:   1065
# T/F: T
# ----------
# Q:   4+844
# A:   848
# T/F: T
# ----------
# Q:   53+44
# A:   97
# T/F: T
# ----------
# Q:   445+69
# A:   514
# T/F: T
# ----------
# Q:   904+18
# A:   922
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 0.0027 - acc: 1.0000 - val_loss: 0.1366 - val_acc: 0.9580
# ----------
# Q:   3+59
# A:   62
# T/F: T
# ----------
# Q:   767+76
# A:   843
# T/F: T
# ----------
# Q:   57+9
# A:   66
# T/F: T
# ----------
# Q:   198+57
# A:   255
# T/F: T
# ----------
# Q:   882+570
# A:   1452
# T/F: T
# ----------
# Q:   979+833
# A:   1822
# T/F: F
# ----------
# Q:   139+30
# A:   169
# T/F: T
# ----------
# Q:   37+866
# A:   903
# T/F: T
# ----------
# Q:   5+825
# A:   830
# T/F: T
# ----------
# Q:   2+847
# A:   849
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 0.0026 - acc: 1.0000 - val_loss: 0.1371 - val_acc: 0.9579
# ----------
# Q:   950+10
# A:   960
# T/F: T
# ----------
# Q:   963+38
# A:   1001
# T/F: T
# ----------
# Q:   6+659
# A:   665
# T/F: T
# ----------
# Q:   504+972
# A:   1486
# T/F: F
# ----------
# Q:   773+50
# A:   823
# T/F: T
# ----------
# Q:   49+980
# A:   1029
# T/F: T
# ----------
# Q:   357+5
# A:   362
# T/F: T
# ----------
# Q:   318+60
# A:   378
# T/F: T
# ----------
# Q:   222+9
# A:   231
# T/F: T
# ----------
# Q:   69+564
# A:   633
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 0.0025 - acc: 1.0000 - val_loss: 0.1369 - val_acc: 0.9590
# ----------
# Q:   101+22
# A:   113
# T/F: F
# ----------
# Q:   805+99
# A:   903
# T/F: F
# ----------
# Q:   142+890
# A:   1032
# T/F: T
# ----------
# Q:   16+289
# A:   305
# T/F: T
# ----------
# Q:   41+86
# A:   127
# T/F: T
# ----------
# Q:   284+650
# A:   944
# T/F: F
# ----------
# Q:   4+520
# A:   524
# T/F: T
# ----------
# Q:   250+29
# A:   279
# T/F: T
# ----------
# Q:   499+62
# A:   561
# T/F: T
# ----------
# Q:   12+272
# A:   284
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 324us/step - loss: 0.0024 - acc: 1.0000 - val_loss: 0.1364 - val_acc: 0.9584
# ----------
# Q:   5+695
# A:   700
# T/F: T
# ----------
# Q:   862+240
# A:   1102
# T/F: T
# ----------
# Q:   139+9
# A:   148
# T/F: T
# ----------
# Q:   615+1
# A:   616
# T/F: T
# ----------
# Q:   17+25
# A:   42
# T/F: T
# ----------
# Q:   3+148
# A:   151
# T/F: T
# ----------
# Q:   312+6
# A:   318
# T/F: T
# ----------
# Q:   44+554
# A:   598
# T/F: T
# ----------
# Q:   831+111
# A:   942
# T/F: T
# ----------
# Q:   970+319
# A:   1299
# T/F: F
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 326us/step - loss: 0.0023 - acc: 1.0000 - val_loss: 0.1384 - val_acc: 0.9590
# ----------
# Q:   266+8
# A:   274
# T/F: T
# ----------
# Q:   56+99
# A:   155
# T/F: T
# ----------
# Q:   209+370
# A:   589
# T/F: F
# ----------
# Q:   528+26
# A:   554
# T/F: T
# ----------
# Q:   75+12
# A:   87
# T/F: T
# ----------
# Q:   858+9
# A:   867
# T/F: T
# ----------
# Q:   25+733
# A:   758
# T/F: T
# ----------
# Q:   639+28
# A:   667
# T/F: T
# ----------
# Q:   680+1
# A:   681
# T/F: T
# ----------
# Q:   32+140
# A:   172
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 329us/step - loss: 0.0023 - acc: 1.0000 - val_loss: 0.1403 - val_acc: 0.9581
# ----------
# Q:   731+36
# A:   767
# T/F: T
# ----------
# Q:   9+929
# A:   938
# T/F: T
# ----------
# Q:   222+0
# A:   222
# T/F: T
# ----------
# Q:   49+130
# A:   179
# T/F: T
# ----------
# Q:   920+123
# A:   1033
# T/F: F
# ----------
# Q:   85+923
# A:   1098
# T/F: F
# ----------
# Q:   64+42
# A:   106
# T/F: T
# ----------
# Q:   542+3
# A:   545
# T/F: T
# ----------
# Q:   539+52
# A:   591
# T/F: T
# ----------
# Q:   881+3
# A:   884
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 329us/step - loss: 0.0022 - acc: 1.0000 - val_loss: 0.1408 - val_acc: 0.9574
# ----------
# Q:   66+551
# A:   617
# T/F: T
# ----------
# Q:   482+78
# A:   560
# T/F: T
# ----------
# Q:   547+364
# A:   912
# T/F: F
# ----------
# Q:   695+93
# A:   788
# T/F: T
# ----------
# Q:   26+727
# A:   753
# T/F: T
# ----------
# Q:   56+96
# A:   152
# T/F: T
# ----------
# Q:   254+310
# A:   574
# T/F: F
# ----------
# Q:   15+940
# A:   955
# T/F: T
# ----------
# Q:   1+203
# A:   204
# T/F: T
# ----------
# Q:   370+1
# A:   371
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 326us/step - loss: 0.0021 - acc: 1.0000 - val_loss: 0.1396 - val_acc: 0.9589
# ----------
# Q:   97+630
# A:   727
# T/F: T
# ----------
# Q:   91+447
# A:   538
# T/F: T
# ----------
# Q:   60+52
# A:   112
# T/F: T
# ----------
# Q:   29+413
# A:   442
# T/F: T
# ----------
# Q:   26+12
# A:   38
# T/F: T
# ----------
# Q:   64+834
# A:   898
# T/F: T
# ----------
# Q:   54+32
# A:   86
# T/F: T
# ----------
# Q:   178+62
# A:   230
# T/F: F
# ----------
# Q:   88+667
# A:   755
# T/F: T
# ----------
# Q:   547+0
# A:   547
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 6s 327us/step - loss: 0.0020 - acc: 1.0000 - val_loss: 0.1414 - val_acc: 0.9582
# ----------
# Q:   25+415
# A:   440
# T/F: T
# ----------
# Q:   4+844
# A:   848
# T/F: T
# ----------
# Q:   23+664
# A:   687
# T/F: T
# ----------
# Q:   995+46
# A:   1031
# T/F: F
# ----------
# Q:   59+450
# A:   509
# T/F: T
# ----------
# Q:   863+19
# A:   882
# T/F: T
# ----------
# Q:   4+245
# A:   249
# T/F: T
# ----------
# Q:   1+335
# A:   336
# T/F: T
# ----------
# Q:   93+80
# A:   173
# T/F: T
# ----------
# Q:   160+82
# A:   242
# T/F: T
# ----------
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 12200/18000 [===================>..........] - ETA: 1s - loss: 0.0019 - acc: 1.0000
